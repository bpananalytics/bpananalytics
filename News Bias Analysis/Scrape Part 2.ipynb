# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install pandas

# Import necessary libraries.
import requests
from bs4 import BeautifulSoup
import pandas

# %%
# The globeandmail

import requests
from bs4 import BeautifulSoup

# Create a session object
session = requests.Session()

# Set a User-Agent header (optional, but often useful)
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'
}

# URL of the webpage to scrape
url = 'https://www.theglobeandmail.com/world/article-kamala-harris-and-donald-trump-locked-in-a-dead-heat-for-the-popular/'

# Send a GET request using the session
response = session.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')  # Use .content to pass the HTML content
    
    # Locate the `h1` tag using the data attribute
    heading = soup.find('h1')
    
    # Extract the text
    heading_text = heading.get_text() if heading else "Heading not found"
    print(heading_text)
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# Kamala Harris and Donald Trump locked in a dead heat for the popular vote, poll finds

# %%
# The globeandmail

import requests
from bs4 import BeautifulSoup

# Create a session object
session = requests.Session()

# Set a User-Agent header (optional, but often useful)
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'
}

# URL of the webpage to scrape
url = 'https://www.theglobeandmail.com/world/article-kamala-harris-and-donald-trump-locked-in-a-dead-heat-for-the-popular/'

# Send a GET request using the session
response = session.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')  # Use .content to pass the HTML content
    
    src_link = soup.find('img', class_='c-image').get('src')
    print(src_link)
    
    
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# https://www.theglobeandmail.com/resizer/v2/GCEUUELCD5EKBOXLJUIRAIZGB4.JPG?auth=0ba7cec40d64887bfd5aff4dea5cad84907c7a832b2014a3f5620896e9d3e2ce&width=600&quality=80

# %%
# The globeandmail

import requests
from bs4 import BeautifulSoup

# Create a session object
session = requests.Session()

# Set a User-Agent header (optional, but often useful)
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'
}

# URL of the webpage to scrape
url = 'https://www.theglobeandmail.com/world/article-kamala-harris-and-donald-trump-locked-in-a-dead-heat-for-the-popular/'

# Send a GET request using the session
response = session.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')  # Use .content to pass the HTML content
    caption = soup.find('span', class_='caption text-gmr-4').get_text()
    print(caption)
    
    
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# Donald Trump and Kamala Harris remain effectively tied even after three of the most tumultuous months in recent American political history.

# %%
# The globeandmail

import requests
from bs4 import BeautifulSoup

# Create a session object
session = requests.Session()

# Set a User-Agent header (optional, but often useful)
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'
}

# URL of the webpage to scrape
url = 'https://www.theglobeandmail.com/world/article-kamala-harris-and-donald-trump-locked-in-a-dead-heat-for-the-popular/'

# Send a GET request using the session
response = session.get(url)

# Check if the request was successful
if response.status_code == 200:
    
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')  # Use .content to pass the HTML content
    
    author = soup.find('span', class_='credit text-gmr-5').text
    print(author)
    
    
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# Eduardo Munoz/Reuters

# %%
# The globeandmail

import requests
from bs4 import BeautifulSoup

# Create a session object
session = requests.Session()

# Set a User-Agent header (optional, but often useful)
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'
}

# URL of the webpage to scrape
url = 'https://www.theglobeandmail.com/world/article-kamala-harris-and-donald-trump-locked-in-a-dead-heat-for-the-popular/'

# Send a GET request using the session
response = session.get(url)

# Extract article 
article_text = ""
article_body = soup.find_all('p', class_='c-article-body_text text-pr-5')

if not article_body:
    paragraphs = soup.find_all('p')
    for para in paragraphs:
        article_text += para.get_text().strip() + "\n"
else:
    for div in article_body:
        paragraphs = div.find_all('p')
        for paragraph in paragraphs:
            article_text += paragraph.get_text().strip() + "\n"

print(article_text)
# Out:
# Donald Trump and Kamala Harris remain effectively tied even after three of the most tumultuous months in recent American political history.Eduardo Munoz/Reuters
# Kamala Harris and Donald Trump are locked in a dead heat for the popular vote, 48 per cent to 48 per cent, the final national poll by The New York Times and Siena College has found, as the Vice-President struggles for an edge over the former president with an electorate that seems impossibly and immovably divided.
# The result, coming less than two weeks before Election Day, and as millions of Americans have already voted, is not encouraging for Harris. In recent elections, Democrats have had an edge in the popular vote even when they have lost the Electoral College and thus the White House. They have been looking to Harris to build a strong national lead as a sign that she would do well in such critical swing states as Michigan, Pennsylvania and Wisconsin.
# ...

# %%
# Import to CSV

import requests
from bs4 import BeautifulSoup
import csv

# Create a session object
session = requests.Session()

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'
}

# URL of the webpage to scrape
url = 'https://www.theglobeandmail.com/world/article-kamala-harris-and-donald-trump-locked-in-a-dead-heat-for-the-popular/'

# Send a GET request using the session
response = session.get(url)


# Title
heading = soup.find('h1')
heading_text = heading.get_text() if heading else "Heading not found"



## Author
soup = BeautifulSoup(response.content, 'html.parser')  # Use .content to pass the HTML content
author = soup.find('span', class_='credit text-gmr-5').text

## Img Link 
soup = BeautifulSoup(response.content, 'html.parser')  # Use .content to pass the HTML content
src_link = soup.find('img', class_='c-image').get('src')


## Caption
caption = soup.find('span', class_='caption text-gmr-4').get_text()



## Text
article_text = ""
if not article_body:
    paragraphs = soup.find_all('p')
    for para in paragraphs:
        article_text += para.get_text().strip() 
else:
    for div in article_body:
        paragraphs = div.find_all('p')
        for paragraph in paragraphs:
            article_text += paragraph.get_text().strip()

# Create a CSV file and write the data
with open('theglobeandmail.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    
    # Write the header
    writer.writerow(['title', 'author', 'image URL', 'caption', 'text'])
    
    # Write the article data
    writer.writerow([heading_text, author, src_link, caption, article_text])

print("Done")
# Out:
# Done

# %%
# Scripps

import requests
from bs4 import BeautifulSoup

# Create a session object
session = requests.Session()

# Set a User-Agent header (optional, but often useful)
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'
}

# URL of the webpage to scrape
url = 'https://www.scrippsnews.com/politics/america-votes/harris-trump-court-suburban-pennsylvania-voters-in-path-to-white-house'

# Send a GET request using the session
response = session.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')  # Use .content to pass the HTML content
    
    # Locate the `h1` tag using the data attribute
    heading = soup.find('h1')
    
    # Extract the text
    heading_text = heading.get_text() if heading else "Heading not found"
    print(heading_text)
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# Harris, Trump court suburban Pennsylvania voters in path to White House

# %%
# Scripps

import requests
from bs4 import BeautifulSoup

# Create a session object
session = requests.Session()

# Set a User-Agent header (optional, but often useful)
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'
}

# URL of the webpage to scrape
url = 'https://www.scrippsnews.com/politics/america-votes/harris-trump-court-suburban-pennsylvania-voters-in-path-to-white-house'

soup = BeautifulSoup(response.content, 'html.parser')  # Use .content to pass the HTML content


# Extract author names
main_content = soup.find('div', class_='left-column')
authors = []
if author_div:
    author_links = author_div.find_all('a')
    for author_link in author_links:
        authors.append(author_link.get_text(strip=True))

print("Authors:")
for author in authors:
    print(author)
    
print(authors)
# Out:
# Authors:
# Haley Bull
# Serena Marshall
# Jacob Gardenswartz
# ['Haley Bull', 'Serena Marshall', 'Jacob Gardenswartz']

# %%
# Scripps
import requests
from bs4 import BeautifulSoup

# Create a session object
session = requests.Session()

# Set a User-Agent header (optional, but often useful)
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'
}

# URL of the webpage to scrape
url = 'https://www.scrippsnews.com/politics/america-votes/harris-trump-court-suburban-pennsylvania-voters-in-path-to-white-house'

soup = BeautifulSoup(response.content, 'html.parser')  # Use .content to pass the HTML content

## Text
main_content = soup.find('div', class_='Page-body ArticlePage-articleBody')

article_text = ""

if not article_body:
    paragraphs = main_content.find_all('p')
    for para in paragraphs:
        article_text += para.get_text().strip() 
else:
    for div in article_body:
        paragraphs = div.find_all('p')
        for paragraph in paragraphs:
            article_text += paragraph.get_text().strip()
            
print(article_text)
# Out:
# The keys to the White House may be decided on the ground in Pennsylvania, where campaigns are blanketing the commonwealth, and the pivotal suburbs.Both former President Donald Trump and Vice President Kamala Harris visited the Philadelphia suburbs this week as they vie for Pennsylvania’s 19 electoral votes, and the suburban residents who could prove crucial to their effort.“We just want to make sure that Kamala wins,” said Rosemary Moller. “Because the alternative is very frightening.”She and her husband, Jeffrey, added to the more than one million door knocks the campaign has completed in the state as volunteers canvass out of 50 campaign offices. They hit the pavement in Montgomery County, a region they too call home.“If you've judged by lawn signs, you'd have to say that, like, 99% of the lawns don't have a sign out at all, so you don't really know what's what's going on,” said Jeffrey Moller.“In our neighborhood,” Rosemary Moller added, “It's a little bit more Kamala than Trump.”
# ...

# %%
# To CSV

# Scripps
import requests
from bs4 import BeautifulSoup

# Create a session object
session = requests.Session()

# Set a User-Agent header (optional, but often useful)
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'
}

# URL of the webpage to scrape
url = 'https://www.scrippsnews.com/politics/america-votes/harris-trump-court-suburban-pennsylvania-voters-in-path-to-white-house'

soup = BeautifulSoup(response.content, 'html.parser')  # Use .content to pass the HTML content

# Get title
heading = soup.find('h1').get_text()
print(heading)


# Extract author names
main_content = soup.find('div', class_='left-column')
authors = []
if author_div:
    author_links = author_div.find_all('a')
    for author_link in author_links:
        authors.append(author_link.get_text(strip=True))

print("Authors:")
for author in authors:
    print(author)
    
print(authors)


## Text
main_content = soup.find('div', class_='Page-body ArticlePage-articleBody')

article_text = ""

if not article_body:
    paragraphs = main_content.find_all('p')
    for para in paragraphs:
        article_text += para.get_text().strip() 
else:
    for div in article_body:
        paragraphs = div.find_all('p')
        for paragraph in paragraphs:
            article_text += paragraph.get_text().strip()
            
print(article_text)

# Create a CSV file and write the data
with open('scripps.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    
    # Write the header
    writer.writerow(['title', 'author', 'text'])
    
    # Write the article data
    writer.writerow([heading, authors, article_text])

print("Done")
# Out:
# Harris, Trump court suburban Pennsylvania voters in path to White House
# Authors:
# Haley Bull
# Serena Marshall
# Jacob Gardenswartz
# ['Haley Bull', 'Serena Marshall', 'Jacob Gardenswartz']
# ...
