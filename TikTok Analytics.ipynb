# %% [markdown]
# # Codes

# %% [markdown]
# Part 1 - Labels

# %%
import pandas
import boto3
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import io
import time

s3 = boto3.resource('s3')
bucket = s3.Bucket('bpbucket24')

print(bucket)

session = boto3.Session()
client = session.client('rekognition')

#I am creating an empty dictionary here
output = {"videoname":[], "labels":[], "confidencescores":[], "timestamps":[]}

for file in bucket.objects.filter(Prefix="videos"):
    #Print image name for each video in the S3 bucket
    print(file.key)
    response = client.start_label_detection(
    Video={
        "S3Object": {
            "Bucket": "bpbucket24",
            "Name": file.key
        }})
    job_id = response["JobId"]
    print(f"{job_id=}")
    while True:
        response = client.get_label_detection(JobId=job_id)
        print(f"{response['JobStatus']=}")
        if response['JobStatus'] == 'IN_PROGRESS':
            print("time.sleep(10)")
            time.sleep(10)
        else:
            break

    next_token = None

    while True:
        if next_token is None:
            response = client.get_label_detection(JobId=job_id)
        else:
            response = client.get_label_detection(JobId=job_id, NextToken=next_token)
        next_token = response.get("NextToken")
        labels = response["Labels"]

        if next_token is None:
            break

    for labelDetection in response['Labels']:
        label = labelDetection['Label']
        if label['Confidence']> 90.00:
            if label['Name'] not in output["labels"]:
                print("Video Name: "+ file.key)
                output["videoname"].append(file.key)
                print("Label: " + label['Name'])
                output["labels"].append(label['Name'])
                print("Confidence: " + str(label['Confidence']))
                output["confidencescores"].append(label['Confidence'])
                print("Timestamp: " + str(labelDetection['Timestamp']))
                output["timestamps"].append(labelDetection['Timestamp'])


#Save results into a CSV file
#The code below fixes the issue of array lengths do not match issue 
results = pandas.DataFrame.from_dict(output, orient="index")
results = results.transpose()
results.to_csv('example3results.csv', index=True, index_label="Index")

print("done")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# s3.Bucket(name='bpbucket24')
# videos/
# job_id='5cbc8cff44bced30eff07bc205e81a19dff836553fc769619db49610d7e193eb'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='FAILED'
# videos/Kim_1.mp4
# job_id='3b489cdfa84d651598377c9649c01f7ad71f8de251026036cd4fdd28278c0137'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Video Name: videos/Kim_1.mp4
# Label: Male
# Confidence: 90.29597473144531
# Timestamp: 38700
# Video Name: videos/Kim_1.mp4
# Label: Man
# Confidence: 90.08468627929688
# Timestamp: 38700
# Video Name: videos/Kim_1.mp4
# Label: Person
# Confidence: 96.89376831054688
# Timestamp: 38700
# Video Name: videos/Kim_1.mp4
# Label: Adult
# Confidence: 97.5428466796875
# Timestamp: 39200
# Video Name: videos/Kim_1.mp4
# Label: Female
# Confidence: 92.63230895996094
# Timestamp: 39200
# Video Name: videos/Kim_1.mp4
# Label: Woman
# Confidence: 92.63230895996094
# Timestamp: 39200
# Video Name: videos/Kim_1.mp4
# Label: Body Part
# Confidence: 90.24151611328125
# Timestamp: 40200
# Video Name: videos/Kim_1.mp4
# Label: Torso
# Confidence: 90.22171783447266
# Timestamp: 40200
# Video Name: videos/Kim_1.mp4
# Label: Clothing
# Confidence: 92.47262573242188
# Timestamp: 41200
# videos/Kim_2.mp4
# job_id='2b775e316289be8eeac27d6ad706722fc5ffc2d7227cde43582ffe82818db51d'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Video Name: videos/Kim_2.mp4
# Label: Face
# Confidence: 92.20004272460938
# Timestamp: 33766
# Video Name: videos/Kim_2.mp4
# Label: Head
# Confidence: 92.6380386352539
# Timestamp: 33766
# Video Name: videos/Kim_2.mp4
# Label: Underwear
# Confidence: 92.07076263427734
# Timestamp: 35766
# Video Name: videos/Kim_2.mp4
# Label: Swimwear
# Confidence: 90.20240783691406
# Timestamp: 36266
# Video Name: videos/Kim_2.mp4
# Label: Lingerie
# Confidence: 92.28104400634766
# Timestamp: 36766
# Video Name: videos/Kim_2.mp4
# Label: Bra
# Confidence: 94.37992095947266
# Timestamp: 37266
# Video Name: videos/Kim_2.mp4
# Label: Photography
# Confidence: 90.3376235961914
# Timestamp: 38266
# Video Name: videos/Kim_2.mp4
# Label: Portrait
# Confidence: 90.3376235961914
# Timestamp: 38266
# Video Name: videos/Kim_2.mp4
# Label: Nature
# Confidence: 95.35426330566406
# Timestamp: 48266
# Video Name: videos/Kim_2.mp4
# Label: Outdoors
# Confidence: 96.16068267822266
# Timestamp: 48266
# videos/Kim_3.mp4
# job_id='183576dd3189b1346f550b74f97e28b2d117163e84bf4ac6f4857e005d93bfe8'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Video Name: videos/Kim_3.mp4
# Label: Accessories
# Confidence: 97.35279083251953
# Timestamp: 21521
# Video Name: videos/Kim_3.mp4
# Label: Earring
# Confidence: 97.29650115966797
# Timestamp: 21521
# Video Name: videos/Kim_3.mp4
# Label: Jewelry
# Confidence: 97.29650115966797
# Timestamp: 21521
# Video Name: videos/Kim_3.mp4
# Label: Blonde
# Confidence: 97.02468872070312
# Timestamp: 23523
# Video Name: videos/Kim_3.mp4
# Label: Hair
# Confidence: 97.02468872070312
# Timestamp: 23523
# Video Name: videos/Kim_3.mp4
# Label: Wedding
# Confidence: 93.59627532958984
# Timestamp: 23523
# videos/Won_1.mp4
# job_id='3c5bc6d59a43ef34163f2a258093d15d2ae4e755baf06a94d3470d3365683218'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Video Name: videos/Won_1.mp4
# Label: Baby
# Confidence: 90.79158020019531
# Timestamp: 2533
# Video Name: videos/Won_1.mp4
# Label: Fitness
# Confidence: 90.12174224853516
# Timestamp: 4516
# Video Name: videos/Won_1.mp4
# Label: Gym
# Confidence: 90.12174224853516
# Timestamp: 4516
# Video Name: videos/Won_1.mp4
# Label: Gym Weights
# Confidence: 90.12174224853516
# Timestamp: 4516
# Video Name: videos/Won_1.mp4
# Label: Sport
# Confidence: 90.12174224853516
# Timestamp: 4516
# Video Name: videos/Won_1.mp4
# Label: Working Out
# Confidence: 90.12174224853516
# Timestamp: 4516
# Video Name: videos/Won_1.mp4
# Label: Bench Press
# Confidence: 93.14005279541016
# Timestamp: 5516
# videos/Won_2.mp4
# job_id='375e78055094a58795250dd504aef60825aebd7c4e3f6aca808000dc79adafc1'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Video Name: videos/Won_2.mp4
# Label: Coat
# Confidence: 90.61336517333984
# Timestamp: 59933
# Video Name: videos/Won_2.mp4
# Label: Cushion
# Confidence: 91.1993179321289
# Timestamp: 59933
# Video Name: videos/Won_2.mp4
# Label: Home Decor
# Confidence: 91.5166015625
# Timestamp: 59933
# Video Name: videos/Won_2.mp4
# Label: Indoors
# Confidence: 97.29479217529297
# Timestamp: 60433
# Video Name: videos/Won_2.mp4
# Label: Interior Design
# Confidence: 97.29479217529297
# Timestamp: 60433
# Video Name: videos/Won_2.mp4
# Label: Shirt
# Confidence: 93.06817626953125
# Timestamp: 60933
# videos/Won_3.mp4
# job_id='93d283174377b3450ab163bdeccaaa8575a196890a38cfaabcfeefd05afcca27'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Video Name: videos/Won_3.mp4
# Label: Boy
# Confidence: 90.18084716796875
# Timestamp: 2033
# Video Name: videos/Won_3.mp4
# Label: Romantic
# Confidence: 90.68704223632812
# Timestamp: 12500
# videos/Won_4.mp4
# job_id='ae93a2cbd6520b1830a655d791be2d39401e24ae5c7864a2c6fe9277dc1871f3'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Video Name: videos/Won_4.mp4
# Label: Performer
# Confidence: 99.99828338623047
# Timestamp: 0
# Video Name: videos/Won_4.mp4
# Label: Solo Performance
# Confidence: 99.99828338623047
# Timestamp: 0
# videos/Won_5.mp4
# job_id='aa1c142bbfefca7702b56de60fe62173c6dd0345e0cf6b1a0075a99e3d8c7352'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Video Name: videos/Won_5.mp4
# Label: Happy
# Confidence: 95.04277801513672
# Timestamp: 520
# Video Name: videos/Won_5.mp4
# Label: Laughing
# Confidence: 94.8965072631836
# Timestamp: 520
# Video Name: videos/Won_5.mp4
# Label: Eating
# Confidence: 91.30860137939453
# Timestamp: 5520
# Video Name: videos/Won_5.mp4
# Label: Food
# Confidence: 91.30860137939453
# Timestamp: 5520
# done

# %% [markdown]
# Part 2 - Text

# %%
import pandas
import boto3
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import io
import time

s3 = boto3.resource('s3')
bucket = s3.Bucket('bpbucket24')

print(bucket)

session = boto3.Session()
client = session.client('rekognition')

#I am creating an empty dictionary here
output = {"videoID":[], "text":[]}

for file in bucket.objects.filter(Prefix="videotext"):
    videoID_list = []
    text_list = []
    #Print image name for each video in the S3 bucket
    print(file.key)
    response = client.start_text_detection(
    Video={
        "S3Object": {
            "Bucket": "bpbucket24",
            "Name": file.key
        }})
    job_id = response["JobId"]
    print(f"{job_id=}")
    while True:
        response = client.get_text_detection(JobId=job_id)
        print(f"{response['JobStatus']=}")
        if response['JobStatus'] == 'IN_PROGRESS':
            print("time.sleep(10)")
            time.sleep(10)
        else:
            break

    next_token = None

    while True:
        if next_token is None:
            response = client.get_text_detection(JobId=job_id)
        else:
            response = client.get_text_detection(JobId=job_id, NextToken=next_token)
            next_token = response.get("NextToken")
        if next_token is None:
            break

    for textDetection in response['TextDetections']:
        text = textDetection['TextDetection']
        #print("Timestamp: " + str(textDetection['Timestamp']))
        if text['Confidence']> 90.00:
            #print("Text Detected: " + text['DetectedText'])
            text_list.append(text['DetectedText'])
            #output["text"].append(text['DetectedText'])
            #print("Video ID:", file.key)
            videoID_list.append(file.key)
            #output["videoID"].append(file.key)
            
    output["text"].append(text_list)
    output["videoID"].append(videoID_list)

#Save results into a CSV file
#The code below fixes the issue of array lengths do not match issue 
results = pandas.DataFrame.from_dict(output)
#Without this you will get a blank first row 
results = results.iloc[1:, :]
results.to_csv('textresult.csv', index=True, index_label="Index")
print("done")
# Out:
# s3.Bucket(name='bpbucket24')
# videotext/
# job_id='bd0d6e81e8f932012699bd29a0e94f60e5e0a1a075f044f84eec06a003d4635f'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='FAILED'
# videotext/Kim_1.mp4
# job_id='c04da9cfd1098348759ace4c8aaf578a19165e6710b3c18c2b2f777725d203e7'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# videotext/Kim_2.mp4
# job_id='a55a77ff153e0c519fb876b99b910e0ba6a304aa25f8df6a8d50265b220dcf05'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# videotext/Kim_3.mp4
# job_id='3f54bbf1f7cd0db6144eb12c029f50b49cfaf107ded99899188822146f90a457'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# videotext/Won_1.mp4
# job_id='778aa56235d48f3f5a7fbc2f64fa4d10d9c1ee5bfecb5349cc57e24c88efc5bb'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# videotext/Won_2.mp4
# job_id='2e16db5e1b6fc8bd564db54b8a25f3fd65e58693ace0e782887489c374a4d730'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# videotext/Won_3.mp4
# job_id='390fc0ac1c00cefba62db445f56f3e489216f3c5969055289293e203a9a4efe4'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# videotext/Won_4.mp4
# job_id='96dd9d11c09ed0e5d60b65576feb1fe7b696b9d73862a334b4f96572a7dabee2'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# videotext/Won_5.mp4
# job_id='1cb3d89c716b6d0d22a957eebaf6539bc12db8778f205654cc587e688113b3d4'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# done

# %% [markdown]
# Part 3 - Celebrity

# %%
import pandas
import boto3
import time

session = boto3.Session()
client = session.client('rekognition')

#I am creating an empty dictionary here
#output = {"videoID""celebrity":[], "furtherinfo":[]}

output = {"videoID":[], "celebrity":[], "furtherinfo":[]}

for file in bucket.objects.filter(Prefix="videotext"):
    
    videoID_list = []

    #I am creating a list her that will contain duplicate celebrity names extracted from the video
    celebritylist =[]

    #This is for the further information data
    furtherinfolist = []

    #Print image name for each video in the S3 bucket
    print(file.key)

    response = client.start_celebrity_recognition(
        Video={
            "S3Object": {
                "Bucket": "bpbucket24"
                , "Name": file.key
            }
        }
    )

    job_id = response["JobId"]
    print(f"{job_id=}")

    while True:
        response = client.get_celebrity_recognition(JobId=job_id)
        print(f"{response['JobStatus']=}")

        if response['JobStatus'] == 'IN_PROGRESS':
            print("time.sleep(10)")
            time.sleep(10)
        else:
            break

    next_token = None

    while True:
        if next_token is None:
            response = client.get_celebrity_recognition(JobId=job_id)
        else:
            response = client.get_celebrity_recognition(JobId=job_id, NextToken=next_token)
        next_token = response.get("NextToken")

        if next_token is None:
            break

    for celebrityRecognition in response['Celebrities']:
        #I used this print to find what data is inside the  response['Celebrities']. I am searching for an ID number
        #print('Celebrity: ' + str(celebrityRecognition['Celebrity']))
        #FYI there is a nested data structure here: celebrityRecognition['Celebrity']['Name']
        print('Celebrity: ' + str(celebrityRecognition['Celebrity']['Name']))
        print('Celebrity: ' + str(celebrityRecognition['Celebrity']['Id']))
        celebrityid = celebrityRecognition['Celebrity']['Id']
        response2 = client.get_celebrity_info(Id=celebrityid)
        print('Further information (if available):')
        for url in response2['Urls']:
            print(url)
            furtherinfolist.append(url)
        celebritylist.append(celebrityRecognition['Celebrity']['Name'])
        #Remove duplicate celebrity names in the list
        celebritylist = list(set(celebritylist))
        #Remove duplicates from the further info list
        furtherinfolist = list(set(furtherinfolist))
        print()

    output["celebrity"].append(celebritylist)
    output["furtherinfo"].append(furtherinfolist)

#Save results into a CSV file
results = pandas.DataFrame.from_dict(output)
results.to_csv('celebrity.csv', index=True, index_label="Index")
print("done")
# Out:
# videotext/
# job_id='c3535c731ec58c2b71d0da4c75e5aec09eec76386e93c9a83c7e1c558cac6e43'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='FAILED'
# videotext/Kim_1.mp4
# job_id='7e07e77a4158e86df7130af8ecbfbfae768e12591beeb6a0a92631e42c6cbccd'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# videotext/Kim_2.mp4
# job_id='1cc5967398d5099acdfb1d54fe133d6e169fc284b39e89ee3979ffb87737937d'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# videotext/Kim_3.mp4
# job_id='7dca7c47273625d31d9056695259cfdf39a664bb3bfde93a7ceb33afca677406'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Jourdan Dunn
# Celebrity: 3UY7hX5
# Further information (if available):
# www.wikidata.org/wiki/Q2357124
# www.imdb.com/name/nm5435984
#
# Celebrity: Jourdan Dunn
# Celebrity: 3UY7hX5
# Further information (if available):
# www.wikidata.org/wiki/Q2357124
# www.imdb.com/name/nm5435984
#
# Celebrity: Judy Landers
# Celebrity: 1tB8uC4B
# Further information (if available):
# www.wikidata.org/wiki/Q4356117
# www.imdb.com/name/nm0484641
#
# videotext/Won_1.mp4
# job_id='fc51046a32b7b631b2181058c6dd8f612adbcd2b67aa3e5b3fce920f47bc8e26'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Nie Yuan
# Celebrity: 2wI8T4z
# Further information (if available):
# www.wikidata.org/wiki/Q835003
# www.imdb.com/name/nm1983064
#
# videotext/Won_2.mp4
# job_id='1aa7be6d8b5773493e8214ff05da589ae84e46d67a5928148bc7a3cd0777db35'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# videotext/Won_3.mp4
# job_id='57da425527e083ba79393bcbc2f858add8b4b7a0dfbf11720791d165241856ec'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# videotext/Won_4.mp4
# job_id='7f1bd6cdc1319ca27945b7010ede453ca408cc71211532450e52179a94071bd4'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# videotext/Won_5.mp4
# job_id='8af2afce281642ab52f115bc92e8bf4de1e3eaa9ff03d4ef5ae52bac61632a96'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Jungkook
# Celebrity: 5edd76
# Further information (if available):
# www.wikidata.org/wiki/Q22338877
# www.imdb.com/name/nm8506461
#
# Celebrity: Jungkook
# Celebrity: 5edd76
# Further information (if available):
# www.wikidata.org/wiki/Q22338877
# www.imdb.com/name/nm8506461
#
# Celebrity: Bai Jinshi
# Celebrity: 1c96cc
# Further information (if available):
# www.wikidata.org/wiki/Q27523289
#
# Celebrity: Jungkook
# Celebrity: 5edd76
# Further information (if available):
# www.wikidata.org/wiki/Q22338877
# www.imdb.com/name/nm8506461
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 83
#      80     output["furtherinfo"].append(furtherinfolist)
#      82 #Save results into a CSV file
# ---> 83 results = pandas.DataFrame.from_dict(output)
#      84 results.to_csv('celebrity.csv', index=True, index_label="Index")
#      85 print("done")
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/frame.py:1917, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1911     raise ValueError(
#    1912         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1913         f"Got '{orient}' instead"
#    1914     )
#    1916 if orient != "tight":
# -> 1917     return cls(data, index=index, columns=columns, dtype=dtype)
#    1918 else:
#    1919     realdata = data["data"]
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
import pandas
import boto3
import time

session = boto3.Session()
client = session.client('rekognition')

#I am creating an empty dictionary here
#output = {"videoID""celebrity":[], "furtherinfo":[]}

output = {"videoID":[], "celebrity":[], "furtherinfo":[]}

for file in bucket.objects.filter(Prefix="videotext"):
    
    videoID_list = []

    #I am creating a list her that will contain duplicate celebrity names extracted from the video
    celebritylist =[]

    #This is for the further information data
    furtherinfolist = []

    #Print image name for each video in the S3 bucket
    print(file.key)

    response = client.start_celebrity_recognition(
        Video={
            "S3Object": {
                "Bucket": "bpbucket24"
                , "Name": file.key
            }
        }
    )

    job_id = response["JobId"]
    print(f"{job_id=}")

    while True:
        response = client.get_celebrity_recognition(JobId=job_id)
        print(f"{response['JobStatus']=}")

        if response['JobStatus'] == 'IN_PROGRESS':
            print("time.sleep(10)")
            time.sleep(10)
        else:
            break

    next_token = None

    while True:
        if next_token is None:
            response = client.get_celebrity_recognition(JobId=job_id)
        else:
            response = client.get_celebrity_recognition(JobId=job_id, NextToken=next_token)
        next_token = response.get("NextToken")

        if next_token is None:
            break

    for celebrityRecognition in response['Celebrities']:
        #I used this print to find what data is inside the  response['Celebrities']. I am searching for an ID number
        #print('Celebrity: ' + str(celebrityRecognition['Celebrity']))
        #FYI there is a nested data structure here: celebrityRecognition['Celebrity']['Name']
        print('Celebrity: ' + str(celebrityRecognition['Celebrity']['Name']))
        print('Celebrity: ' + str(celebrityRecognition['Celebrity']['Id']))
        celebrityid = celebrityRecognition['Celebrity']['Id']
        response2 = client.get_celebrity_info(Id=celebrityid)
        print('Further information (if available):')
        for url in response2['Urls']:
            print(url)
            furtherinfolist.append(url)
        celebritylist.append(celebrityRecognition['Celebrity']['Name'])
        #Remove duplicate celebrity names in the list
        celebritylist = list(set(celebritylist))
        #Remove duplicates from the further info list
        furtherinfolist = list(set(furtherinfolist))
        print()
        
    output["videoID"].append(videoID_list)
    output["celebrity"].append(celebritylist)
    output["furtherinfo"].append(furtherinfolist)

#Save results into a CSV file
results = pandas.DataFrame.from_dict(output)
results.to_csv('celebrity.csv', index=True, index_label="Index")
print("done")
# Out:
# videotext/
# job_id='168bd23fb15cc6f2263436e3a1880ac9dbbd74431daa176ed6ee14eee820bdcf'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='FAILED'
# videotext/Kim_1.mp4
# job_id='87edb910a648d315bb5b595ca3436dfd2ec4d722fd8a40245365efecf2514ea4'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# Celebrity: Laura Cremaschi
# Celebrity: d880ca
# Further information (if available):
# www.wikidata.org/wiki/Q65966463
# www.imdb.com/name/nm6713058
#
# videotext/Kim_2.mp4
# job_id='707e1dcba868081293288c280add2f1f829b14056e18a60af5764b3bef2f497c'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# Celebrity: Huda Kattan
# Celebrity: d828e4
# Further information (if available):
# www.wikidata.org/wiki/Q42966319
#
# videotext/Kim_3.mp4
# job_id='4e0327f86c9669afea2ba3c7a3e7308dd37413c13b4b619e889bae5deb906882'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Jourdan Dunn
# Celebrity: 3UY7hX5
# Further information (if available):
# www.wikidata.org/wiki/Q2357124
# www.imdb.com/name/nm5435984
#
# Celebrity: Jourdan Dunn
# Celebrity: 3UY7hX5
# Further information (if available):
# www.wikidata.org/wiki/Q2357124
# www.imdb.com/name/nm5435984
#
# Celebrity: Judy Landers
# Celebrity: 1tB8uC4B
# Further information (if available):
# www.wikidata.org/wiki/Q4356117
# www.imdb.com/name/nm0484641
#
# videotext/Won_1.mp4
# job_id='f1ccc6e130a64cdd8950e5ee91bd3721c793ad3572d393c635e2caabde786095'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Nie Yuan
# Celebrity: 2wI8T4z
# Further information (if available):
# www.wikidata.org/wiki/Q835003
# www.imdb.com/name/nm1983064
#
# videotext/Won_2.mp4
# job_id='a2bc8f4c446bb74c9104b9d92a8eeeabb0249f7a61bc5e5bba7a7ca0391cd899'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# Celebrity: Qi Guangpu
# Celebrity: 424ecc
# Further information (if available):
# www.wikidata.org/wiki/Q955639
#
# videotext/Won_3.mp4
# job_id='b483a5e261dd912b2fd3b549465eab9130b8605f1ededb874d99e88435124c74'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# videotext/Won_4.mp4
# job_id='e3f4cfd5b0ba46c6e6afba3e334243580bd5d3aaa13be9109c83085872b3e573'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# videotext/Won_5.mp4
# job_id='63f7eb303a8f5c35629ba7d5fb3cd1675e5598b9f37c7fa5df39f5a027b82af9'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# Celebrity: Jungkook
# Celebrity: 5edd76
# Further information (if available):
# www.wikidata.org/wiki/Q22338877
# www.imdb.com/name/nm8506461
#
# Celebrity: Jungkook
# Celebrity: 5edd76
# Further information (if available):
# www.wikidata.org/wiki/Q22338877
# www.imdb.com/name/nm8506461
#
# Celebrity: Bai Jinshi
# Celebrity: 1c96cc
# Further information (if available):
# www.wikidata.org/wiki/Q27523289
#
# Celebrity: Jungkook
# Celebrity: 5edd76
# Further information (if available):
# www.wikidata.org/wiki/Q22338877
# www.imdb.com/name/nm8506461
#
# done

# %% [markdown]
# Part 8 - Explicit Review

# %%
import pandas
import boto3
import time

session = boto3.Session()
client = session.client('rekognition')

#I am creating an empty dictionary here
output = {"celebrity":[], "furtherinfo":[]}

videoID_list = []

#I am creating a list her that will contain duplicate celebrity names extracted from the video
celebritylist =[]

#This is for the further information data
furtherinfolist = []

response = client.start_content_moderation(
    Video={
        "S3Object": {
            "Bucket": "bpbucket24"
            , "Name": "Kim_1.mp4"
        }
    }
)

job_id = response["JobId"]
print(f"{job_id=}")

while True:
    response = client.get_content_moderation(JobId=job_id)
    print(f"{response['JobStatus']=}")
    if response['JobStatus'] == 'IN_PROGRESS':
        print("time.sleep(10)")
        time.sleep(10)
    else:
        break

next_token = None

while True:
    if next_token is None:
        response = client.get_content_moderation(JobId=job_id)
    else:
        response = client.get_content_moderation(JobId=job_id, NextToken=next_token)
    next_token = response.get("NextToken")
    if next_token is None:
        break

#print(response['ModerationLabels'])
if len(response['ModerationLabels']) == 0:
    print("No Problem Detected")
else:
    for contentModerationDetection in response['ModerationLabels']:
        print(contentModerationDetection)        
        print('Label: ' + str(contentModerationDetection['ModerationLabel']['Name']))
        print('Confidence: ' + str(contentModerationDetection['ModerationLabel']['Confidence']))
        print('Parent category: ' + str(contentModerationDetection['ModerationLabel']['ParentName']))
        print('Timestamp: ' + str(contentModerationDetection['Timestamp']))
        print()
print("done")
# Out:
# job_id='979a2e116426f285be8ccbfb85c36a62ed5efc55d86c67aa6d7a06179d580f5f'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# {'Timestamp': 0, 'ModerationLabel': {'Confidence': 92.21143341064453, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 92.21143341064453
# Parent category:
# Timestamp: 0
#
# {'Timestamp': 0, 'ModerationLabel': {'Confidence': 92.21143341064453, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 92.21143341064453
# Parent category: Explicit
# Timestamp: 0
#
# {'Timestamp': 0, 'ModerationLabel': {'Confidence': 85.16895294189453, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 85.16895294189453
# Parent category: Explicit Nudity
# Timestamp: 0
#
# {'Timestamp': 0, 'ModerationLabel': {'Confidence': 92.21143341064453, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 92.21143341064453
# Parent category: Explicit Nudity
# Timestamp: 0
#
# {'Timestamp': 500, 'ModerationLabel': {'Confidence': 96.31130981445312, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 96.31130981445312
# Parent category:
# Timestamp: 500
#
# {'Timestamp': 500, 'ModerationLabel': {'Confidence': 96.31130981445312, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 96.31130981445312
# Parent category: Explicit
# Timestamp: 500
#
# {'Timestamp': 500, 'ModerationLabel': {'Confidence': 83.14288330078125, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 83.14288330078125
# Parent category: Explicit Nudity
# Timestamp: 500
#
# {'Timestamp': 500, 'ModerationLabel': {'Confidence': 96.31130981445312, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 96.31130981445312
# Parent category: Explicit Nudity
# Timestamp: 500
#
# {'Timestamp': 1000, 'ModerationLabel': {'Confidence': 88.98219299316406, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 88.98219299316406
# Parent category:
# Timestamp: 1000
#
# {'Timestamp': 1000, 'ModerationLabel': {'Confidence': 88.98219299316406, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 88.98219299316406
# Parent category: Explicit
# Timestamp: 1000
#
# {'Timestamp': 1000, 'ModerationLabel': {'Confidence': 76.92153930664062, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 76.92153930664062
# Parent category: Explicit Nudity
# Timestamp: 1000
#
# {'Timestamp': 1000, 'ModerationLabel': {'Confidence': 88.98219299316406, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 88.98219299316406
# Parent category: Explicit Nudity
# Timestamp: 1000
#
# {'Timestamp': 1000, 'ModerationLabel': {'Confidence': 55.11246871948242, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 55.11246871948242
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 1000
#
# {'Timestamp': 1000, 'ModerationLabel': {'Confidence': 55.1512451171875, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 55.1512451171875
# Parent category:
# Timestamp: 1000
#
# {'Timestamp': 1000, 'ModerationLabel': {'Confidence': 54.639564514160156, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 54.639564514160156
# Parent category: Non-Explicit Nudity
# Timestamp: 1000
#
# {'Timestamp': 1500, 'ModerationLabel': {'Confidence': 86.89767456054688, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 86.89767456054688
# Parent category:
# Timestamp: 1500
#
# {'Timestamp': 1500, 'ModerationLabel': {'Confidence': 86.89767456054688, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 86.89767456054688
# Parent category: Explicit
# Timestamp: 1500
#
# {'Timestamp': 1500, 'ModerationLabel': {'Confidence': 86.89767456054688, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 86.89767456054688
# Parent category: Explicit Nudity
# Timestamp: 1500
#
# {'Timestamp': 1500, 'ModerationLabel': {'Confidence': 77.32493591308594, 'Name': 'Exposed Male Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Genitalia
# Confidence: 77.32493591308594
# Parent category: Explicit Nudity
# Timestamp: 1500
#
# {'Timestamp': 2500, 'ModerationLabel': {'Confidence': 72.92537689208984, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 72.92537689208984
# Parent category:
# Timestamp: 2500
#
# {'Timestamp': 2500, 'ModerationLabel': {'Confidence': 72.4751968383789, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 72.4751968383789
# Parent category: Explicit
# Timestamp: 2500
#
# {'Timestamp': 2500, 'ModerationLabel': {'Confidence': 72.46833801269531, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 72.46833801269531
# Parent category: Explicit Nudity
# Timestamp: 2500
#
# {'Timestamp': 2500, 'ModerationLabel': {'Confidence': 71.44976043701172, 'Name': 'Exposed Male Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Genitalia
# Confidence: 71.44976043701172
# Parent category: Explicit Nudity
# Timestamp: 2500
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 77.73213958740234, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 77.73213958740234
# Parent category:
# Timestamp: 9500
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 77.6878433227539, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 77.6878433227539
# Parent category: Explicit
# Timestamp: 9500
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 60.572265625, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 60.572265625
# Parent category: Explicit Nudity
# Timestamp: 9500
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 76.6129150390625, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 76.6129150390625
# Parent category: Explicit Nudity
# Timestamp: 9500
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 50.87008285522461, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 50.87008285522461
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 9500
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 50.87008285522461, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 50.87008285522461
# Parent category:
# Timestamp: 9500
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 79.53136444091797, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 79.53136444091797
# Parent category:
# Timestamp: 10000
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 79.51182556152344, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 79.51182556152344
# Parent category: Explicit
# Timestamp: 10000
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 75.65062713623047, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 75.65062713623047
# Parent category: Explicit Nudity
# Timestamp: 10000
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 77.8919906616211, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 77.8919906616211
# Parent category: Explicit Nudity
# Timestamp: 10000
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 68.2950439453125, 'Name': 'Exposed Male Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Genitalia
# Confidence: 68.2950439453125
# Parent category: Explicit Nudity
# Timestamp: 10000
#
# {'Timestamp': 10500, 'ModerationLabel': {'Confidence': 69.18487548828125, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 69.18487548828125
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 10500
#
# {'Timestamp': 10500, 'ModerationLabel': {'Confidence': 69.18487548828125, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 69.18487548828125
# Parent category:
# Timestamp: 10500
#
# {'Timestamp': 10500, 'ModerationLabel': {'Confidence': 66.11344909667969, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 66.11344909667969
# Parent category: Non-Explicit Nudity
# Timestamp: 10500
#
# {'Timestamp': 12500, 'ModerationLabel': {'Confidence': 68.96797180175781, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 68.96797180175781
# Parent category:
# Timestamp: 12500
#
# {'Timestamp': 12500, 'ModerationLabel': {'Confidence': 67.6120376586914, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 67.6120376586914
# Parent category: Explicit
# Timestamp: 12500
#
# {'Timestamp': 12500, 'ModerationLabel': {'Confidence': 68.90908813476562, 'Name': 'Explicit Sexual Activity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Sexual Activity
# Confidence: 68.90908813476562
# Parent category: Explicit
# Timestamp: 12500
#
# {'Timestamp': 12500, 'ModerationLabel': {'Confidence': 67.58679962158203, 'Name': 'Exposed Male Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Genitalia
# Confidence: 67.58679962158203
# Parent category: Explicit Nudity
# Timestamp: 12500
#
# {'Timestamp': 15500, 'ModerationLabel': {'Confidence': 57.82626724243164, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 57.82626724243164
# Parent category:
# Timestamp: 15500
#
# {'Timestamp': 16000, 'ModerationLabel': {'Confidence': 75.11636352539062, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 75.11636352539062
# Parent category:
# Timestamp: 16000
#
# {'Timestamp': 16000, 'ModerationLabel': {'Confidence': 71.41851806640625, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 71.41851806640625
# Parent category: Explicit
# Timestamp: 16000
#
# {'Timestamp': 16000, 'ModerationLabel': {'Confidence': 51.8742561340332, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 51.8742561340332
# Parent category: Explicit Nudity
# Timestamp: 16000
#
# {'Timestamp': 16000, 'ModerationLabel': {'Confidence': 69.30447387695312, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 69.30447387695312
# Parent category: Explicit Nudity
# Timestamp: 16000
#
# {'Timestamp': 24000, 'ModerationLabel': {'Confidence': 81.95492553710938, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 81.95492553710938
# Parent category:
# Timestamp: 24000
#
# {'Timestamp': 24000, 'ModerationLabel': {'Confidence': 80.0929183959961, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 80.0929183959961
# Parent category: Explicit
# Timestamp: 24000
#
# {'Timestamp': 24000, 'ModerationLabel': {'Confidence': 76.03472900390625, 'Name': 'Explicit Sexual Activity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Sexual Activity
# Confidence: 76.03472900390625
# Parent category: Explicit
# Timestamp: 24000
#
# {'Timestamp': 24000, 'ModerationLabel': {'Confidence': 78.47810363769531, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 78.47810363769531
# Parent category: Explicit Nudity
# Timestamp: 24000
#
# {'Timestamp': 24000, 'ModerationLabel': {'Confidence': 71.020751953125, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 71.020751953125
# Parent category: Explicit Nudity
# Timestamp: 24000
#
# {'Timestamp': 24500, 'ModerationLabel': {'Confidence': 88.8650894165039, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 88.8650894165039
# Parent category:
# Timestamp: 24500
#
# {'Timestamp': 24500, 'ModerationLabel': {'Confidence': 86.95675659179688, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 86.95675659179688
# Parent category: Explicit
# Timestamp: 24500
#
# {'Timestamp': 24500, 'ModerationLabel': {'Confidence': 76.65038299560547, 'Name': 'Explicit Sexual Activity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Sexual Activity
# Confidence: 76.65038299560547
# Parent category: Explicit
# Timestamp: 24500
#
# {'Timestamp': 24500, 'ModerationLabel': {'Confidence': 84.90098571777344, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 84.90098571777344
# Parent category: Explicit Nudity
# Timestamp: 24500
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 88.58689880371094, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 88.58689880371094
# Parent category:
# Timestamp: 25000
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 88.27104949951172, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 88.27104949951172
# Parent category: Explicit
# Timestamp: 25000
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 83.52906036376953, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 83.52906036376953
# Parent category: Explicit Nudity
# Timestamp: 25000
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 62.1265754699707, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 62.1265754699707
# Parent category: Swimwear or Underwear
# Timestamp: 25000
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 71.44512939453125, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 71.44512939453125
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 25000
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 72.20535278320312, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 72.20535278320312
# Parent category:
# Timestamp: 25000
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 67.12348937988281, 'Name': 'Partially Exposed Buttocks', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Buttocks
# Confidence: 67.12348937988281
# Parent category: Non-Explicit Nudity
# Timestamp: 25000
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 62.1265754699707, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 62.1265754699707
# Parent category:
# Timestamp: 25000
#
# {'Timestamp': 25500, 'ModerationLabel': {'Confidence': 79.63307189941406, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 79.63307189941406
# Parent category:
# Timestamp: 25500
#
# {'Timestamp': 25500, 'ModerationLabel': {'Confidence': 79.52668762207031, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 79.52668762207031
# Parent category: Explicit
# Timestamp: 25500
#
# {'Timestamp': 25500, 'ModerationLabel': {'Confidence': 68.89215850830078, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 68.89215850830078
# Parent category: Explicit Nudity
# Timestamp: 25500
#
# {'Timestamp': 32000, 'ModerationLabel': {'Confidence': 69.83072662353516, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 69.83072662353516
# Parent category:
# Timestamp: 32000
#
# {'Timestamp': 32000, 'ModerationLabel': {'Confidence': 69.81159210205078, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 69.81159210205078
# Parent category: Explicit
# Timestamp: 32000
#
# {'Timestamp': 32000, 'ModerationLabel': {'Confidence': 69.67555236816406, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 69.67555236816406
# Parent category: Explicit Nudity
# Timestamp: 32000
#
# {'Timestamp': 32000, 'ModerationLabel': {'Confidence': 66.44017028808594, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 66.44017028808594
# Parent category: Explicit Nudity
# Timestamp: 32000
#
# {'Timestamp': 33000, 'ModerationLabel': {'Confidence': 80.8814468383789, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 80.8814468383789
# Parent category: Swimwear or Underwear
# Timestamp: 33000
#
# {'Timestamp': 33000, 'ModerationLabel': {'Confidence': 75.22321319580078, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 75.22321319580078
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 33000
#
# {'Timestamp': 33000, 'ModerationLabel': {'Confidence': 75.22321319580078, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 75.22321319580078
# Parent category:
# Timestamp: 33000
#
# {'Timestamp': 33000, 'ModerationLabel': {'Confidence': 72.91056060791016, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 72.91056060791016
# Parent category: Non-Explicit Nudity
# Timestamp: 33000
#
# {'Timestamp': 33000, 'ModerationLabel': {'Confidence': 80.8814468383789, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 80.8814468383789
# Parent category:
# Timestamp: 33000
#
# {'Timestamp': 33500, 'ModerationLabel': {'Confidence': 56.869590759277344, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 56.869590759277344
# Parent category: Swimwear or Underwear
# Timestamp: 33500
#
# {'Timestamp': 33500, 'ModerationLabel': {'Confidence': 79.10999298095703, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 79.10999298095703
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 33500
#
# {'Timestamp': 33500, 'ModerationLabel': {'Confidence': 79.10999298095703, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 79.10999298095703
# Parent category:
# Timestamp: 33500
#
# {'Timestamp': 33500, 'ModerationLabel': {'Confidence': 74.48468017578125, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 74.48468017578125
# Parent category: Non-Explicit Nudity
# Timestamp: 33500
#
# {'Timestamp': 33500, 'ModerationLabel': {'Confidence': 56.869590759277344, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 56.869590759277344
# Parent category:
# Timestamp: 33500
#
# {'Timestamp': 34000, 'ModerationLabel': {'Confidence': 77.4200439453125, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 77.4200439453125
# Parent category: Swimwear or Underwear
# Timestamp: 34000
#
# {'Timestamp': 34000, 'ModerationLabel': {'Confidence': 77.9628677368164, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 77.9628677368164
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 34000
#
# {'Timestamp': 34000, 'ModerationLabel': {'Confidence': 79.26242065429688, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 79.26242065429688
# Parent category:
# Timestamp: 34000
#
# {'Timestamp': 34000, 'ModerationLabel': {'Confidence': 67.02284240722656, 'Name': 'Partially Exposed Buttocks', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Buttocks
# Confidence: 67.02284240722656
# Parent category: Non-Explicit Nudity
# Timestamp: 34000
#
# {'Timestamp': 34000, 'ModerationLabel': {'Confidence': 77.4200439453125, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 77.4200439453125
# Parent category:
# Timestamp: 34000
#
# {'Timestamp': 35000, 'ModerationLabel': {'Confidence': 65.50004577636719, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 65.50004577636719
# Parent category:
# Timestamp: 35000
#
# {'Timestamp': 35000, 'ModerationLabel': {'Confidence': 65.49977111816406, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 65.49977111816406
# Parent category: Explicit
# Timestamp: 35000
#
# {'Timestamp': 35000, 'ModerationLabel': {'Confidence': 65.49977111816406, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 65.49977111816406
# Parent category: Explicit Nudity
# Timestamp: 35000
#
# {'Timestamp': 35500, 'ModerationLabel': {'Confidence': 59.44532775878906, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 59.44532775878906
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 35500
#
# {'Timestamp': 35500, 'ModerationLabel': {'Confidence': 62.044437408447266, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 62.044437408447266
# Parent category:
# Timestamp: 35500
#
# {'Timestamp': 35500, 'ModerationLabel': {'Confidence': 57.791465759277344, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 57.791465759277344
# Parent category: Non-Explicit Nudity
# Timestamp: 35500
#
# {'Timestamp': 36500, 'ModerationLabel': {'Confidence': 67.16557312011719, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 67.16557312011719
# Parent category: Swimwear or Underwear
# Timestamp: 36500
#
# {'Timestamp': 36500, 'ModerationLabel': {'Confidence': 51.25777816772461, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 51.25777816772461
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 36500
#
# {'Timestamp': 36500, 'ModerationLabel': {'Confidence': 51.25777816772461, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 51.25777816772461
# Parent category:
# Timestamp: 36500
#
# {'Timestamp': 36500, 'ModerationLabel': {'Confidence': 67.16571044921875, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 67.16571044921875
# Parent category:
# Timestamp: 36500
#
# {'Timestamp': 38500, 'ModerationLabel': {'Confidence': 83.05387115478516, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 83.05387115478516
# Parent category:
# Timestamp: 38500
#
# {'Timestamp': 38500, 'ModerationLabel': {'Confidence': 83.05292510986328, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 83.05292510986328
# Parent category: Explicit
# Timestamp: 38500
#
# {'Timestamp': 38500, 'ModerationLabel': {'Confidence': 83.05258178710938, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 83.05258178710938
# Parent category: Explicit Nudity
# Timestamp: 38500
#
# {'Timestamp': 38500, 'ModerationLabel': {'Confidence': 75.09318542480469, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 75.09318542480469
# Parent category: Swimwear or Underwear
# Timestamp: 38500
#
# {'Timestamp': 38500, 'ModerationLabel': {'Confidence': 75.09325408935547, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 75.09325408935547
# Parent category:
# Timestamp: 38500
#
# {'Timestamp': 39000, 'ModerationLabel': {'Confidence': 86.83082580566406, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 86.83082580566406
# Parent category:
# Timestamp: 39000
#
# {'Timestamp': 39000, 'ModerationLabel': {'Confidence': 86.83082580566406, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 86.83082580566406
# Parent category: Explicit
# Timestamp: 39000
#
# {'Timestamp': 39000, 'ModerationLabel': {'Confidence': 86.83079528808594, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 86.83079528808594
# Parent category: Explicit Nudity
# Timestamp: 39000
#
# {'Timestamp': 39000, 'ModerationLabel': {'Confidence': 81.38935089111328, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 81.38935089111328
# Parent category: Swimwear or Underwear
# Timestamp: 39000
#
# {'Timestamp': 39000, 'ModerationLabel': {'Confidence': 81.38937377929688, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 81.38937377929688
# Parent category:
# Timestamp: 39000
#
# {'Timestamp': 39500, 'ModerationLabel': {'Confidence': 80.70381164550781, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 80.70381164550781
# Parent category:
# Timestamp: 39500
#
# {'Timestamp': 39500, 'ModerationLabel': {'Confidence': 80.70381164550781, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 80.70381164550781
# Parent category: Explicit
# Timestamp: 39500
#
# {'Timestamp': 39500, 'ModerationLabel': {'Confidence': 80.70381164550781, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 80.70381164550781
# Parent category: Explicit Nudity
# Timestamp: 39500
#
# {'Timestamp': 39500, 'ModerationLabel': {'Confidence': 79.72413635253906, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 79.72413635253906
# Parent category: Swimwear or Underwear
# Timestamp: 39500
#
# {'Timestamp': 39500, 'ModerationLabel': {'Confidence': 53.64739990234375, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 53.64739990234375
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 39500
#
# {'Timestamp': 39500, 'ModerationLabel': {'Confidence': 53.64739990234375, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 53.64739990234375
# Parent category:
# Timestamp: 39500
#
# {'Timestamp': 39500, 'ModerationLabel': {'Confidence': 53.600624084472656, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 53.600624084472656
# Parent category: Non-Explicit Nudity
# Timestamp: 39500
#
# {'Timestamp': 39500, 'ModerationLabel': {'Confidence': 79.72413635253906, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 79.72413635253906
# Parent category:
# Timestamp: 39500
#
# {'Timestamp': 40000, 'ModerationLabel': {'Confidence': 64.28050231933594, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 64.28050231933594
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 40000
#
# {'Timestamp': 40000, 'ModerationLabel': {'Confidence': 64.28050231933594, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 64.28050231933594
# Parent category:
# Timestamp: 40000
#
# {'Timestamp': 40000, 'ModerationLabel': {'Confidence': 64.28050231933594, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 64.28050231933594
# Parent category: Non-Explicit Nudity
# Timestamp: 40000
#
# {'Timestamp': 41000, 'ModerationLabel': {'Confidence': 82.83879852294922, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 82.83879852294922
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 41000
#
# {'Timestamp': 41000, 'ModerationLabel': {'Confidence': 82.83879852294922, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 82.83879852294922
# Parent category:
# Timestamp: 41000
#
# {'Timestamp': 41000, 'ModerationLabel': {'Confidence': 82.83879852294922, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 82.83879852294922
# Parent category: Non-Explicit Nudity
# Timestamp: 41000
#
# {'Timestamp': 41500, 'ModerationLabel': {'Confidence': 84.07552337646484, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 84.07552337646484
# Parent category: Swimwear or Underwear
# Timestamp: 41500
#
# {'Timestamp': 41500, 'ModerationLabel': {'Confidence': 70.26089477539062, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 70.26089477539062
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 41500
#
# {'Timestamp': 41500, 'ModerationLabel': {'Confidence': 70.26089477539062, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 70.26089477539062
# Parent category:
# Timestamp: 41500
#
# {'Timestamp': 41500, 'ModerationLabel': {'Confidence': 70.26089477539062, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 70.26089477539062
# Parent category: Non-Explicit Nudity
# Timestamp: 41500
#
# {'Timestamp': 41500, 'ModerationLabel': {'Confidence': 84.07552337646484, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 84.07552337646484
# Parent category:
# Timestamp: 41500
#
# {'Timestamp': 42000, 'ModerationLabel': {'Confidence': 87.67171478271484, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 87.67171478271484
# Parent category: Swimwear or Underwear
# Timestamp: 42000
#
# {'Timestamp': 42000, 'ModerationLabel': {'Confidence': 90.92210388183594, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 90.92210388183594
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 42000
#
# {'Timestamp': 42000, 'ModerationLabel': {'Confidence': 90.92210388183594, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 90.92210388183594
# Parent category:
# Timestamp: 42000
#
# {'Timestamp': 42000, 'ModerationLabel': {'Confidence': 90.92210388183594, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 90.92210388183594
# Parent category: Non-Explicit Nudity
# Timestamp: 42000
#
# {'Timestamp': 42000, 'ModerationLabel': {'Confidence': 87.67171478271484, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 87.67171478271484
# Parent category:
# Timestamp: 42000
#
# {'Timestamp': 42500, 'ModerationLabel': {'Confidence': 94.14063262939453, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 94.14063262939453
# Parent category: Swimwear or Underwear
# Timestamp: 42500
#
# {'Timestamp': 42500, 'ModerationLabel': {'Confidence': 89.56793975830078, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 89.56793975830078
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 42500
#
# {'Timestamp': 42500, 'ModerationLabel': {'Confidence': 89.56793975830078, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 89.56793975830078
# Parent category:
# Timestamp: 42500
#
# {'Timestamp': 42500, 'ModerationLabel': {'Confidence': 89.56793975830078, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 89.56793975830078
# Parent category: Non-Explicit Nudity
# Timestamp: 42500
#
# {'Timestamp': 42500, 'ModerationLabel': {'Confidence': 94.14063262939453, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 94.14063262939453
# Parent category:
# Timestamp: 42500
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 76.9605484008789, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 76.9605484008789
# Parent category:
# Timestamp: 43000
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 76.9605484008789, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 76.9605484008789
# Parent category: Explicit
# Timestamp: 43000
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 76.9605484008789, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 76.9605484008789
# Parent category: Explicit Nudity
# Timestamp: 43000
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 93.86705017089844, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 93.86705017089844
# Parent category: Swimwear or Underwear
# Timestamp: 43000
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 86.2364501953125, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 86.2364501953125
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 43000
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 86.2364501953125, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 86.2364501953125
# Parent category:
# Timestamp: 43000
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 86.2364501953125, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 86.2364501953125
# Parent category: Non-Explicit Nudity
# Timestamp: 43000
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 93.86705017089844, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 93.86705017089844
# Parent category:
# Timestamp: 43000
#
# done

# %%
import pandas
import boto3
import time

session = boto3.Session()
client = session.client('rekognition')

#I am creating an empty dictionary here
output = {"celebrity":[], "furtherinfo":[]}

videoID_list = []

#I am creating a list her that will contain duplicate celebrity names extracted from the video
celebritylist =[]

#This is for the further information data
furtherinfolist = []

response = client.start_content_moderation(
    Video={
        "S3Object": {
            "Bucket": "bpbucket24"
            , "Name": "Kim_2.mp4"
        }
    }
)

job_id = response["JobId"]
print(f"{job_id=}")

while True:
    response = client.get_content_moderation(JobId=job_id)
    print(f"{response['JobStatus']=}")
    if response['JobStatus'] == 'IN_PROGRESS':
        print("time.sleep(10)")
        time.sleep(10)
    else:
        break

next_token = None

while True:
    if next_token is None:
        response = client.get_content_moderation(JobId=job_id)
    else:
        response = client.get_content_moderation(JobId=job_id, NextToken=next_token)
    next_token = response.get("NextToken")
    if next_token is None:
        break

#print(response['ModerationLabels'])
if len(response['ModerationLabels']) == 0:
    print("No Problem Detected")
else:
    for contentModerationDetection in response['ModerationLabels']:
        print(contentModerationDetection)        
        print('Label: ' + str(contentModerationDetection['ModerationLabel']['Name']))
        print('Confidence: ' + str(contentModerationDetection['ModerationLabel']['Confidence']))
        print('Parent category: ' + str(contentModerationDetection['ModerationLabel']['ParentName']))
        print('Timestamp: ' + str(contentModerationDetection['Timestamp']))
        print()
print("done")
# Out:
# job_id='b6facfed7f0f67e25e455f9dc1774436db7406694bf340917e6f2edc59e4f3ec'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# {'Timestamp': 0, 'ModerationLabel': {'Confidence': 88.92416381835938, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 88.92416381835938
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 0
#
# {'Timestamp': 0, 'ModerationLabel': {'Confidence': 88.92416381835938, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 88.92416381835938
# Parent category:
# Timestamp: 0
#
# {'Timestamp': 0, 'ModerationLabel': {'Confidence': 88.92416381835938, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 88.92416381835938
# Parent category: Non-Explicit Nudity
# Timestamp: 0
#
# {'Timestamp': 500, 'ModerationLabel': {'Confidence': 83.27471160888672, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 83.27471160888672
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 500
#
# {'Timestamp': 500, 'ModerationLabel': {'Confidence': 83.27471160888672, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 83.27471160888672
# Parent category:
# Timestamp: 500
#
# {'Timestamp': 500, 'ModerationLabel': {'Confidence': 83.27314758300781, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 83.27314758300781
# Parent category: Non-Explicit Nudity
# Timestamp: 500
#
# {'Timestamp': 4000, 'ModerationLabel': {'Confidence': 76.44127655029297, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 76.44127655029297
# Parent category: Swimwear or Underwear
# Timestamp: 4000
#
# {'Timestamp': 4000, 'ModerationLabel': {'Confidence': 82.12117767333984, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 82.12117767333984
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 4000
#
# {'Timestamp': 4000, 'ModerationLabel': {'Confidence': 82.12117767333984, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 82.12117767333984
# Parent category:
# Timestamp: 4000
#
# {'Timestamp': 4000, 'ModerationLabel': {'Confidence': 82.12117767333984, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 82.12117767333984
# Parent category: Non-Explicit Nudity
# Timestamp: 4000
#
# {'Timestamp': 4000, 'ModerationLabel': {'Confidence': 76.44127655029297, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 76.44127655029297
# Parent category:
# Timestamp: 4000
#
# {'Timestamp': 4500, 'ModerationLabel': {'Confidence': 79.27079010009766, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 79.27079010009766
# Parent category: Swimwear or Underwear
# Timestamp: 4500
#
# {'Timestamp': 4500, 'ModerationLabel': {'Confidence': 91.9662094116211, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 91.9662094116211
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 4500
#
# {'Timestamp': 4500, 'ModerationLabel': {'Confidence': 91.9662094116211, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 91.9662094116211
# Parent category:
# Timestamp: 4500
#
# {'Timestamp': 4500, 'ModerationLabel': {'Confidence': 91.9662094116211, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 91.9662094116211
# Parent category: Non-Explicit Nudity
# Timestamp: 4500
#
# {'Timestamp': 4500, 'ModerationLabel': {'Confidence': 79.27079010009766, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 79.27079010009766
# Parent category:
# Timestamp: 4500
#
# {'Timestamp': 5000, 'ModerationLabel': {'Confidence': 54.80868148803711, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 54.80868148803711
# Parent category: Swimwear or Underwear
# Timestamp: 5000
#
# {'Timestamp': 5000, 'ModerationLabel': {'Confidence': 97.36517333984375, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 97.36517333984375
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 5000
#
# {'Timestamp': 5000, 'ModerationLabel': {'Confidence': 97.36517333984375, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 97.36517333984375
# Parent category:
# Timestamp: 5000
#
# {'Timestamp': 5000, 'ModerationLabel': {'Confidence': 97.36517333984375, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 97.36517333984375
# Parent category: Non-Explicit Nudity
# Timestamp: 5000
#
# {'Timestamp': 5000, 'ModerationLabel': {'Confidence': 54.80868148803711, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 54.80868148803711
# Parent category:
# Timestamp: 5000
#
# {'Timestamp': 5500, 'ModerationLabel': {'Confidence': 71.3469009399414, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 71.3469009399414
# Parent category: Swimwear or Underwear
# Timestamp: 5500
#
# {'Timestamp': 5500, 'ModerationLabel': {'Confidence': 91.63294982910156, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 91.63294982910156
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 5500
#
# {'Timestamp': 5500, 'ModerationLabel': {'Confidence': 91.63294982910156, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 91.63294982910156
# Parent category:
# Timestamp: 5500
#
# {'Timestamp': 5500, 'ModerationLabel': {'Confidence': 91.63294982910156, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 91.63294982910156
# Parent category: Non-Explicit Nudity
# Timestamp: 5500
#
# {'Timestamp': 5500, 'ModerationLabel': {'Confidence': 71.3469009399414, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 71.3469009399414
# Parent category:
# Timestamp: 5500
#
# {'Timestamp': 6000, 'ModerationLabel': {'Confidence': 82.16262817382812, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 82.16262817382812
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 6000
#
# {'Timestamp': 6000, 'ModerationLabel': {'Confidence': 82.16262817382812, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 82.16262817382812
# Parent category:
# Timestamp: 6000
#
# {'Timestamp': 6000, 'ModerationLabel': {'Confidence': 82.16262817382812, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 82.16262817382812
# Parent category: Non-Explicit Nudity
# Timestamp: 6000
#
# {'Timestamp': 10500, 'ModerationLabel': {'Confidence': 84.89839935302734, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 84.89839935302734
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 10500
#
# {'Timestamp': 10500, 'ModerationLabel': {'Confidence': 84.89839935302734, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 84.89839935302734
# Parent category:
# Timestamp: 10500
#
# {'Timestamp': 10500, 'ModerationLabel': {'Confidence': 84.89839935302734, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 84.89839935302734
# Parent category: Non-Explicit Nudity
# Timestamp: 10500
#
# {'Timestamp': 11000, 'ModerationLabel': {'Confidence': 89.87334442138672, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 89.87334442138672
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 11000
#
# {'Timestamp': 11000, 'ModerationLabel': {'Confidence': 89.87334442138672, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 89.87334442138672
# Parent category:
# Timestamp: 11000
#
# {'Timestamp': 11000, 'ModerationLabel': {'Confidence': 89.87334442138672, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 89.87334442138672
# Parent category: Non-Explicit Nudity
# Timestamp: 11000
#
# {'Timestamp': 11500, 'ModerationLabel': {'Confidence': 93.8136215209961, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 93.8136215209961
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 11500
#
# {'Timestamp': 11500, 'ModerationLabel': {'Confidence': 93.8136215209961, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 93.8136215209961
# Parent category:
# Timestamp: 11500
#
# {'Timestamp': 11500, 'ModerationLabel': {'Confidence': 93.8136215209961, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 93.8136215209961
# Parent category: Non-Explicit Nudity
# Timestamp: 11500
#
# {'Timestamp': 12000, 'ModerationLabel': {'Confidence': 94.08525848388672, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 94.08525848388672
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 12000
#
# {'Timestamp': 12000, 'ModerationLabel': {'Confidence': 94.08525848388672, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 94.08525848388672
# Parent category:
# Timestamp: 12000
#
# {'Timestamp': 12000, 'ModerationLabel': {'Confidence': 94.08525848388672, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 94.08525848388672
# Parent category: Non-Explicit Nudity
# Timestamp: 12000
#
# {'Timestamp': 12500, 'ModerationLabel': {'Confidence': 94.79441833496094, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 94.79441833496094
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 12500
#
# {'Timestamp': 12500, 'ModerationLabel': {'Confidence': 94.79441833496094, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 94.79441833496094
# Parent category:
# Timestamp: 12500
#
# {'Timestamp': 12500, 'ModerationLabel': {'Confidence': 94.79441833496094, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 94.79441833496094
# Parent category: Non-Explicit Nudity
# Timestamp: 12500
#
# {'Timestamp': 13000, 'ModerationLabel': {'Confidence': 97.82787322998047, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 97.82787322998047
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 13000
#
# {'Timestamp': 13000, 'ModerationLabel': {'Confidence': 97.82787322998047, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 97.82787322998047
# Parent category:
# Timestamp: 13000
#
# {'Timestamp': 13000, 'ModerationLabel': {'Confidence': 97.82787322998047, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 97.82787322998047
# Parent category: Non-Explicit Nudity
# Timestamp: 13000
#
# {'Timestamp': 13500, 'ModerationLabel': {'Confidence': 96.68794250488281, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 96.68794250488281
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 13500
#
# {'Timestamp': 13500, 'ModerationLabel': {'Confidence': 96.68794250488281, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 96.68794250488281
# Parent category:
# Timestamp: 13500
#
# {'Timestamp': 13500, 'ModerationLabel': {'Confidence': 96.68794250488281, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 96.68794250488281
# Parent category: Non-Explicit Nudity
# Timestamp: 13500
#
# {'Timestamp': 14000, 'ModerationLabel': {'Confidence': 98.9880142211914, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 98.9880142211914
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 14000
#
# {'Timestamp': 14000, 'ModerationLabel': {'Confidence': 98.9880142211914, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 98.9880142211914
# Parent category:
# Timestamp: 14000
#
# {'Timestamp': 14000, 'ModerationLabel': {'Confidence': 98.9880142211914, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 98.9880142211914
# Parent category: Non-Explicit Nudity
# Timestamp: 14000
#
# {'Timestamp': 14500, 'ModerationLabel': {'Confidence': 97.50236511230469, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 97.50236511230469
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 14500
#
# {'Timestamp': 14500, 'ModerationLabel': {'Confidence': 97.50236511230469, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 97.50236511230469
# Parent category:
# Timestamp: 14500
#
# {'Timestamp': 14500, 'ModerationLabel': {'Confidence': 97.50236511230469, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 97.50236511230469
# Parent category: Non-Explicit Nudity
# Timestamp: 14500
#
# {'Timestamp': 15000, 'ModerationLabel': {'Confidence': 94.79449462890625, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 94.79449462890625
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 15000
#
# {'Timestamp': 15000, 'ModerationLabel': {'Confidence': 94.79449462890625, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 94.79449462890625
# Parent category:
# Timestamp: 15000
#
# {'Timestamp': 15000, 'ModerationLabel': {'Confidence': 94.7905502319336, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 94.7905502319336
# Parent category: Non-Explicit Nudity
# Timestamp: 15000
#
# {'Timestamp': 15500, 'ModerationLabel': {'Confidence': 85.71943664550781, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 85.71943664550781
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 15500
#
# {'Timestamp': 15500, 'ModerationLabel': {'Confidence': 85.71943664550781, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 85.71943664550781
# Parent category:
# Timestamp: 15500
#
# {'Timestamp': 15500, 'ModerationLabel': {'Confidence': 85.71153259277344, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 85.71153259277344
# Parent category: Non-Explicit Nudity
# Timestamp: 15500
#
# {'Timestamp': 20000, 'ModerationLabel': {'Confidence': 84.47799682617188, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 84.47799682617188
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 20000
#
# {'Timestamp': 20000, 'ModerationLabel': {'Confidence': 84.47799682617188, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 84.47799682617188
# Parent category:
# Timestamp: 20000
#
# {'Timestamp': 20000, 'ModerationLabel': {'Confidence': 84.47628021240234, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 84.47628021240234
# Parent category: Non-Explicit Nudity
# Timestamp: 20000
#
# {'Timestamp': 20500, 'ModerationLabel': {'Confidence': 70.66238403320312, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 70.66238403320312
# Parent category: Swimwear or Underwear
# Timestamp: 20500
#
# {'Timestamp': 20500, 'ModerationLabel': {'Confidence': 89.5118179321289, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 89.5118179321289
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 20500
#
# {'Timestamp': 20500, 'ModerationLabel': {'Confidence': 89.5118179321289, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 89.5118179321289
# Parent category:
# Timestamp: 20500
#
# {'Timestamp': 20500, 'ModerationLabel': {'Confidence': 89.51095581054688, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 89.51095581054688
# Parent category: Non-Explicit Nudity
# Timestamp: 20500
#
# {'Timestamp': 20500, 'ModerationLabel': {'Confidence': 70.66238403320312, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 70.66238403320312
# Parent category:
# Timestamp: 20500
#
# {'Timestamp': 21000, 'ModerationLabel': {'Confidence': 56.24700927734375, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 56.24700927734375
# Parent category: Swimwear or Underwear
# Timestamp: 21000
#
# {'Timestamp': 21000, 'ModerationLabel': {'Confidence': 97.32330322265625, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 97.32330322265625
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 21000
#
# {'Timestamp': 21000, 'ModerationLabel': {'Confidence': 97.32330322265625, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 97.32330322265625
# Parent category:
# Timestamp: 21000
#
# {'Timestamp': 21000, 'ModerationLabel': {'Confidence': 97.32330322265625, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 97.32330322265625
# Parent category: Non-Explicit Nudity
# Timestamp: 21000
#
# {'Timestamp': 21000, 'ModerationLabel': {'Confidence': 56.24700927734375, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 56.24700927734375
# Parent category:
# Timestamp: 21000
#
# {'Timestamp': 21500, 'ModerationLabel': {'Confidence': 71.52592468261719, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 71.52592468261719
# Parent category: Swimwear or Underwear
# Timestamp: 21500
#
# {'Timestamp': 21500, 'ModerationLabel': {'Confidence': 96.95723724365234, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 96.95723724365234
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 21500
#
# {'Timestamp': 21500, 'ModerationLabel': {'Confidence': 96.95723724365234, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 96.95723724365234
# Parent category:
# Timestamp: 21500
#
# {'Timestamp': 21500, 'ModerationLabel': {'Confidence': 96.95723724365234, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 96.95723724365234
# Parent category: Non-Explicit Nudity
# Timestamp: 21500
#
# {'Timestamp': 21500, 'ModerationLabel': {'Confidence': 71.52592468261719, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 71.52592468261719
# Parent category:
# Timestamp: 21500
#
# {'Timestamp': 22000, 'ModerationLabel': {'Confidence': 97.89807891845703, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 97.89807891845703
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 22000
#
# {'Timestamp': 22000, 'ModerationLabel': {'Confidence': 97.89807891845703, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 97.89807891845703
# Parent category:
# Timestamp: 22000
#
# {'Timestamp': 22000, 'ModerationLabel': {'Confidence': 97.89807891845703, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 97.89807891845703
# Parent category: Non-Explicit Nudity
# Timestamp: 22000
#
# {'Timestamp': 22500, 'ModerationLabel': {'Confidence': 80.81090545654297, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 80.81090545654297
# Parent category: Swimwear or Underwear
# Timestamp: 22500
#
# {'Timestamp': 22500, 'ModerationLabel': {'Confidence': 91.98211669921875, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 91.98211669921875
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 22500
#
# {'Timestamp': 22500, 'ModerationLabel': {'Confidence': 91.98211669921875, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 91.98211669921875
# Parent category:
# Timestamp: 22500
#
# {'Timestamp': 22500, 'ModerationLabel': {'Confidence': 91.98211669921875, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 91.98211669921875
# Parent category: Non-Explicit Nudity
# Timestamp: 22500
#
# {'Timestamp': 22500, 'ModerationLabel': {'Confidence': 80.81090545654297, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 80.81090545654297
# Parent category:
# Timestamp: 22500
#
# {'Timestamp': 23000, 'ModerationLabel': {'Confidence': 76.79116821289062, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 76.79116821289062
# Parent category: Swimwear or Underwear
# Timestamp: 23000
#
# {'Timestamp': 23000, 'ModerationLabel': {'Confidence': 83.5684585571289, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 83.5684585571289
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 23000
#
# {'Timestamp': 23000, 'ModerationLabel': {'Confidence': 83.5684585571289, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 83.5684585571289
# Parent category:
# Timestamp: 23000
#
# {'Timestamp': 23000, 'ModerationLabel': {'Confidence': 83.5684585571289, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 83.5684585571289
# Parent category: Non-Explicit Nudity
# Timestamp: 23000
#
# {'Timestamp': 23000, 'ModerationLabel': {'Confidence': 76.79118347167969, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 76.79118347167969
# Parent category:
# Timestamp: 23000
#
# {'Timestamp': 24500, 'ModerationLabel': {'Confidence': 86.38153076171875, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 86.38153076171875
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 24500
#
# {'Timestamp': 24500, 'ModerationLabel': {'Confidence': 86.38153076171875, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 86.38153076171875
# Parent category:
# Timestamp: 24500
#
# {'Timestamp': 24500, 'ModerationLabel': {'Confidence': 86.38153076171875, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 86.38153076171875
# Parent category: Non-Explicit Nudity
# Timestamp: 24500
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 58.62567138671875, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 58.62567138671875
# Parent category: Swimwear or Underwear
# Timestamp: 25000
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 92.59832763671875, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 92.59832763671875
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 25000
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 92.59832763671875, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 92.59832763671875
# Parent category:
# Timestamp: 25000
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 92.59832763671875, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 92.59832763671875
# Parent category: Non-Explicit Nudity
# Timestamp: 25000
#
# {'Timestamp': 25000, 'ModerationLabel': {'Confidence': 58.62567901611328, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 58.62567901611328
# Parent category:
# Timestamp: 25000
#
# {'Timestamp': 25500, 'ModerationLabel': {'Confidence': 96.15382385253906, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 96.15382385253906
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 25500
#
# {'Timestamp': 25500, 'ModerationLabel': {'Confidence': 96.15382385253906, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 96.15382385253906
# Parent category:
# Timestamp: 25500
#
# {'Timestamp': 25500, 'ModerationLabel': {'Confidence': 96.15382385253906, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 96.15382385253906
# Parent category: Non-Explicit Nudity
# Timestamp: 25500
#
# {'Timestamp': 26000, 'ModerationLabel': {'Confidence': 98.84857177734375, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 98.84857177734375
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 26000
#
# {'Timestamp': 26000, 'ModerationLabel': {'Confidence': 98.84857177734375, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 98.84857177734375
# Parent category:
# Timestamp: 26000
#
# {'Timestamp': 26000, 'ModerationLabel': {'Confidence': 98.84857177734375, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 98.84857177734375
# Parent category: Non-Explicit Nudity
# Timestamp: 26000
#
# {'Timestamp': 26500, 'ModerationLabel': {'Confidence': 98.85599517822266, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 98.85599517822266
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 26500
#
# {'Timestamp': 26500, 'ModerationLabel': {'Confidence': 98.85599517822266, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 98.85599517822266
# Parent category:
# Timestamp: 26500
#
# {'Timestamp': 26500, 'ModerationLabel': {'Confidence': 98.85599517822266, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 98.85599517822266
# Parent category: Non-Explicit Nudity
# Timestamp: 26500
#
# {'Timestamp': 27000, 'ModerationLabel': {'Confidence': 55.332427978515625, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 55.332427978515625
# Parent category: Swimwear or Underwear
# Timestamp: 27000
#
# {'Timestamp': 27000, 'ModerationLabel': {'Confidence': 97.64949035644531, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 97.64949035644531
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 27000
#
# {'Timestamp': 27000, 'ModerationLabel': {'Confidence': 97.64949035644531, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 97.64949035644531
# Parent category:
# Timestamp: 27000
#
# {'Timestamp': 27000, 'ModerationLabel': {'Confidence': 97.64949035644531, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 97.64949035644531
# Parent category: Non-Explicit Nudity
# Timestamp: 27000
#
# {'Timestamp': 27000, 'ModerationLabel': {'Confidence': 55.332427978515625, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 55.332427978515625
# Parent category:
# Timestamp: 27000
#
# {'Timestamp': 27500, 'ModerationLabel': {'Confidence': 94.71784973144531, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 94.71784973144531
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 27500
#
# {'Timestamp': 27500, 'ModerationLabel': {'Confidence': 94.71784973144531, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 94.71784973144531
# Parent category:
# Timestamp: 27500
#
# {'Timestamp': 27500, 'ModerationLabel': {'Confidence': 94.71784973144531, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 94.71784973144531
# Parent category: Non-Explicit Nudity
# Timestamp: 27500
#
# {'Timestamp': 28000, 'ModerationLabel': {'Confidence': 86.1286849975586, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 86.1286849975586
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 28000
#
# {'Timestamp': 28000, 'ModerationLabel': {'Confidence': 86.1286849975586, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 86.1286849975586
# Parent category:
# Timestamp: 28000
#
# {'Timestamp': 28000, 'ModerationLabel': {'Confidence': 86.1286849975586, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 86.1286849975586
# Parent category: Non-Explicit Nudity
# Timestamp: 28000
#
# {'Timestamp': 29000, 'ModerationLabel': {'Confidence': 57.84660720825195, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 57.84660720825195
# Parent category:
# Timestamp: 29000
#
# {'Timestamp': 29000, 'ModerationLabel': {'Confidence': 57.84463119506836, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 57.84463119506836
# Parent category: Explicit
# Timestamp: 29000
#
# {'Timestamp': 29000, 'ModerationLabel': {'Confidence': 57.844139099121094, 'Name': 'Exposed Buttocks or Anus', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Buttocks or Anus
# Confidence: 57.844139099121094
# Parent category: Explicit Nudity
# Timestamp: 29000
#
# {'Timestamp': 30000, 'ModerationLabel': {'Confidence': 64.72576141357422, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 64.72576141357422
# Parent category: Swimwear or Underwear
# Timestamp: 30000
#
# {'Timestamp': 30000, 'ModerationLabel': {'Confidence': 83.77561950683594, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 83.77561950683594
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 30000
#
# {'Timestamp': 30000, 'ModerationLabel': {'Confidence': 83.77561950683594, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 83.77561950683594
# Parent category:
# Timestamp: 30000
#
# {'Timestamp': 30000, 'ModerationLabel': {'Confidence': 83.77413177490234, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 83.77413177490234
# Parent category: Non-Explicit Nudity
# Timestamp: 30000
#
# {'Timestamp': 30000, 'ModerationLabel': {'Confidence': 64.72576141357422, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 64.72576141357422
# Parent category:
# Timestamp: 30000
#
# {'Timestamp': 30500, 'ModerationLabel': {'Confidence': 92.27640533447266, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 92.27640533447266
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 30500
#
# {'Timestamp': 30500, 'ModerationLabel': {'Confidence': 92.27640533447266, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 92.27640533447266
# Parent category:
# Timestamp: 30500
#
# {'Timestamp': 30500, 'ModerationLabel': {'Confidence': 92.275634765625, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 92.275634765625
# Parent category: Non-Explicit Nudity
# Timestamp: 30500
#
# {'Timestamp': 31000, 'ModerationLabel': {'Confidence': 86.07764434814453, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 86.07764434814453
# Parent category: Swimwear or Underwear
# Timestamp: 31000
#
# {'Timestamp': 31000, 'ModerationLabel': {'Confidence': 94.8561782836914, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 94.8561782836914
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 31000
#
# {'Timestamp': 31000, 'ModerationLabel': {'Confidence': 94.8561782836914, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 94.8561782836914
# Parent category:
# Timestamp: 31000
#
# {'Timestamp': 31000, 'ModerationLabel': {'Confidence': 94.8561782836914, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 94.8561782836914
# Parent category: Non-Explicit Nudity
# Timestamp: 31000
#
# {'Timestamp': 31000, 'ModerationLabel': {'Confidence': 86.07764434814453, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 86.07764434814453
# Parent category:
# Timestamp: 31000
#
# {'Timestamp': 31500, 'ModerationLabel': {'Confidence': 89.5506820678711, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 89.5506820678711
# Parent category: Swimwear or Underwear
# Timestamp: 31500
#
# {'Timestamp': 31500, 'ModerationLabel': {'Confidence': 93.93760681152344, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 93.93760681152344
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 31500
#
# {'Timestamp': 31500, 'ModerationLabel': {'Confidence': 93.93760681152344, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 93.93760681152344
# Parent category:
# Timestamp: 31500
#
# {'Timestamp': 31500, 'ModerationLabel': {'Confidence': 93.93760681152344, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 93.93760681152344
# Parent category: Non-Explicit Nudity
# Timestamp: 31500
#
# {'Timestamp': 31500, 'ModerationLabel': {'Confidence': 89.5506820678711, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 89.5506820678711
# Parent category:
# Timestamp: 31500
#
# {'Timestamp': 32000, 'ModerationLabel': {'Confidence': 87.28866577148438, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 87.28866577148438
# Parent category: Swimwear or Underwear
# Timestamp: 32000
#
# {'Timestamp': 32000, 'ModerationLabel': {'Confidence': 95.8237075805664, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 95.8237075805664
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 32000
#
# {'Timestamp': 32000, 'ModerationLabel': {'Confidence': 95.8237075805664, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 95.8237075805664
# Parent category:
# Timestamp: 32000
#
# {'Timestamp': 32000, 'ModerationLabel': {'Confidence': 95.8237075805664, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 95.8237075805664
# Parent category: Non-Explicit Nudity
# Timestamp: 32000
#
# {'Timestamp': 32000, 'ModerationLabel': {'Confidence': 87.28866577148438, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 87.28866577148438
# Parent category:
# Timestamp: 32000
#
# {'Timestamp': 32500, 'ModerationLabel': {'Confidence': 89.57991027832031, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 89.57991027832031
# Parent category: Swimwear or Underwear
# Timestamp: 32500
#
# {'Timestamp': 32500, 'ModerationLabel': {'Confidence': 95.39361572265625, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 95.39361572265625
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 32500
#
# ...
# Parent category:
# Timestamp: 36500
#
# {'Timestamp': 36500, 'ModerationLabel': {'Confidence': 94.71818542480469, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 94.71818542480469
# Parent category: Non-Explicit Nudity
# Timestamp: 36500
#
# {'Timestamp': 36500, 'ModerationLabel': {'Confidence': 75.86758422851562, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 75.86758422851562
# Parent category:
# Timestamp: 36500
#
# {'Timestamp': 37000, 'ModerationLabel': {'Confidence': 97.73764038085938, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 97.73764038085938
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 37000
#
# {'Timestamp': 37000, 'ModerationLabel': {'Confidence': 97.73764038085938, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 97.73764038085938
# Parent category:
# Timestamp: 37000
#
# {'Timestamp': 37000, 'ModerationLabel': {'Confidence': 97.73764038085938, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 97.73764038085938
# Parent category: Non-Explicit Nudity
# Timestamp: 37000
#
# {'Timestamp': 37500, 'ModerationLabel': {'Confidence': 90.6480941772461, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 90.6480941772461
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 37500
#
# {'Timestamp': 37500, 'ModerationLabel': {'Confidence': 90.6480941772461, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 90.6480941772461
# Parent category:
# Timestamp: 37500
#
# {'Timestamp': 37500, 'ModerationLabel': {'Confidence': 90.6480941772461, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 90.6480941772461
# Parent category: Non-Explicit Nudity
# Timestamp: 37500
#
# {'Timestamp': 38000, 'ModerationLabel': {'Confidence': 81.38169860839844, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 81.38169860839844
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 38000
#
# {'Timestamp': 38000, 'ModerationLabel': {'Confidence': 81.38169860839844, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 81.38169860839844
# Parent category:
# Timestamp: 38000
#
# {'Timestamp': 38000, 'ModerationLabel': {'Confidence': 81.38169860839844, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 81.38169860839844
# Parent category: Non-Explicit Nudity
# Timestamp: 38000
#
# {'Timestamp': 39500, 'ModerationLabel': {'Confidence': 83.07965087890625, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 83.07965087890625
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 39500
#
# {'Timestamp': 39500, 'ModerationLabel': {'Confidence': 83.07965087890625, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 83.07965087890625
# Parent category:
# Timestamp: 39500
#
# {'Timestamp': 39500, 'ModerationLabel': {'Confidence': 83.07965087890625, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 83.07965087890625
# Parent category: Non-Explicit Nudity
# Timestamp: 39500
#
# {'Timestamp': 40000, 'ModerationLabel': {'Confidence': 75.45652770996094, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 75.45652770996094
# Parent category: Swimwear or Underwear
# Timestamp: 40000
#
# {'Timestamp': 40000, 'ModerationLabel': {'Confidence': 90.96393585205078, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 90.96393585205078
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 40000
#
# {'Timestamp': 40000, 'ModerationLabel': {'Confidence': 90.96393585205078, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 90.96393585205078
# Parent category:
# Timestamp: 40000
#
# {'Timestamp': 40000, 'ModerationLabel': {'Confidence': 90.96393585205078, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 90.96393585205078
# Parent category: Non-Explicit Nudity
# Timestamp: 40000
#
# {'Timestamp': 40000, 'ModerationLabel': {'Confidence': 75.45652770996094, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 75.45652770996094
# Parent category:
# Timestamp: 40000
#
# {'Timestamp': 40500, 'ModerationLabel': {'Confidence': 61.16804504394531, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 61.16804504394531
# Parent category: Swimwear or Underwear
# Timestamp: 40500
#
# {'Timestamp': 40500, 'ModerationLabel': {'Confidence': 92.51953887939453, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 92.51953887939453
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 40500
#
# {'Timestamp': 40500, 'ModerationLabel': {'Confidence': 92.51953887939453, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 92.51953887939453
# Parent category:
# Timestamp: 40500
#
# {'Timestamp': 40500, 'ModerationLabel': {'Confidence': 92.51953887939453, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 92.51953887939453
# Parent category: Non-Explicit Nudity
# Timestamp: 40500
#
# {'Timestamp': 40500, 'ModerationLabel': {'Confidence': 61.16804504394531, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 61.16804504394531
# Parent category:
# Timestamp: 40500
#
# {'Timestamp': 41000, 'ModerationLabel': {'Confidence': 77.42346954345703, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 77.42346954345703
# Parent category: Swimwear or Underwear
# Timestamp: 41000
#
# {'Timestamp': 41000, 'ModerationLabel': {'Confidence': 95.60997772216797, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 95.60997772216797
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 41000
#
# {'Timestamp': 41000, 'ModerationLabel': {'Confidence': 95.60997772216797, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 95.60997772216797
# Parent category:
# Timestamp: 41000
#
# {'Timestamp': 41000, 'ModerationLabel': {'Confidence': 95.60997772216797, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 95.60997772216797
# Parent category: Non-Explicit Nudity
# Timestamp: 41000
#
# {'Timestamp': 41000, 'ModerationLabel': {'Confidence': 77.42346954345703, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 77.42346954345703
# Parent category:
# Timestamp: 41000
#
# {'Timestamp': 41500, 'ModerationLabel': {'Confidence': 98.49688720703125, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 98.49688720703125
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 41500
#
# {'Timestamp': 41500, 'ModerationLabel': {'Confidence': 98.49688720703125, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 98.49688720703125
# Parent category:
# Timestamp: 41500
#
# {'Timestamp': 41500, 'ModerationLabel': {'Confidence': 98.49688720703125, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 98.49688720703125
# Parent category: Non-Explicit Nudity
# Timestamp: 41500
#
# {'Timestamp': 42000, 'ModerationLabel': {'Confidence': 75.18460083007812, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 75.18460083007812
# Parent category: Swimwear or Underwear
# Timestamp: 42000
#
# {'Timestamp': 42000, 'ModerationLabel': {'Confidence': 94.93838500976562, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 94.93838500976562
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 42000
#
# {'Timestamp': 42000, 'ModerationLabel': {'Confidence': 94.93838500976562, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 94.93838500976562
# Parent category:
# Timestamp: 42000
#
# {'Timestamp': 42000, 'ModerationLabel': {'Confidence': 94.93838500976562, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 94.93838500976562
# Parent category: Non-Explicit Nudity
# Timestamp: 42000
#
# {'Timestamp': 42000, 'ModerationLabel': {'Confidence': 75.18460083007812, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 75.18460083007812
# Parent category:
# Timestamp: 42000
#
# {'Timestamp': 42500, 'ModerationLabel': {'Confidence': 98.42535400390625, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 98.42535400390625
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 42500
#
# {'Timestamp': 42500, 'ModerationLabel': {'Confidence': 98.42535400390625, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 98.42535400390625
# Parent category:
# Timestamp: 42500
#
# {'Timestamp': 42500, 'ModerationLabel': {'Confidence': 98.42535400390625, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 98.42535400390625
# Parent category: Non-Explicit Nudity
# Timestamp: 42500
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 50.52321243286133, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 50.52321243286133
# Parent category: Swimwear or Underwear
# Timestamp: 43000
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 93.16551208496094, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 93.16551208496094
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 43000
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 93.16551208496094, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 93.16551208496094
# Parent category:
# Timestamp: 43000
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 93.16551208496094, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 93.16551208496094
# Parent category: Non-Explicit Nudity
# Timestamp: 43000
#
# {'Timestamp': 43000, 'ModerationLabel': {'Confidence': 50.52321243286133, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 50.52321243286133
# Parent category:
# Timestamp: 43000
#
# {'Timestamp': 43500, 'ModerationLabel': {'Confidence': 72.84457397460938, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 72.84457397460938
# Parent category: Swimwear or Underwear
# Timestamp: 43500
#
# {'Timestamp': 43500, 'ModerationLabel': {'Confidence': 81.07554626464844, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 81.07554626464844
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 43500
#
# {'Timestamp': 43500, 'ModerationLabel': {'Confidence': 81.07554626464844, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 81.07554626464844
# Parent category:
# Timestamp: 43500
#
# {'Timestamp': 43500, 'ModerationLabel': {'Confidence': 81.07554626464844, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 81.07554626464844
# Parent category: Non-Explicit Nudity
# Timestamp: 43500
#
# {'Timestamp': 43500, 'ModerationLabel': {'Confidence': 72.84457397460938, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 72.84457397460938
# Parent category:
# Timestamp: 43500
#
# done

# %%
import pandas
import boto3
import time

session = boto3.Session()
client = session.client('rekognition')

#I am creating an empty dictionary here
output = {"celebrity":[], "furtherinfo":[]}

videoID_list = []

#I am creating a list her that will contain duplicate celebrity names extracted from the video
celebritylist =[]

#This is for the further information data
furtherinfolist = []

response = client.start_content_moderation(
    Video={
        "S3Object": {
            "Bucket": "bpbucket24"
            , "Name": "Kim_3.mp4"
        }
    }
)

job_id = response["JobId"]
print(f"{job_id=}")

while True:
    response = client.get_content_moderation(JobId=job_id)
    print(f"{response['JobStatus']=}")
    if response['JobStatus'] == 'IN_PROGRESS':
        print("time.sleep(10)")
        time.sleep(10)
    else:
        break

next_token = None

while True:
    if next_token is None:
        response = client.get_content_moderation(JobId=job_id)
    else:
        response = client.get_content_moderation(JobId=job_id, NextToken=next_token)
    next_token = response.get("NextToken")
    if next_token is None:
        break

#print(response['ModerationLabels'])
if len(response['ModerationLabels']) == 0:
    print("No Problem Detected")
else:
    for contentModerationDetection in response['ModerationLabels']:
        print(contentModerationDetection)        
        print('Label: ' + str(contentModerationDetection['ModerationLabel']['Name']))
        print('Confidence: ' + str(contentModerationDetection['ModerationLabel']['Confidence']))
        print('Parent category: ' + str(contentModerationDetection['ModerationLabel']['ParentName']))
        print('Timestamp: ' + str(contentModerationDetection['Timestamp']))
        print()
print("done")
# Out:
# job_id='7d9c58afc1bb01e3178a4218f8beb5eeabd8521e8543433b4c79a1686093640e'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# {'Timestamp': 8008, 'ModerationLabel': {'Confidence': 81.43177795410156, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 81.43177795410156
# Parent category: Swimwear or Underwear
# Timestamp: 8008
#
# {'Timestamp': 8008, 'ModerationLabel': {'Confidence': 85.3780517578125, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 85.3780517578125
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 8008
#
# {'Timestamp': 8008, 'ModerationLabel': {'Confidence': 85.3780517578125, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 85.3780517578125
# Parent category:
# Timestamp: 8008
#
# {'Timestamp': 8008, 'ModerationLabel': {'Confidence': 85.3780517578125, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 85.3780517578125
# Parent category: Non-Explicit Nudity
# Timestamp: 8008
#
# {'Timestamp': 8008, 'ModerationLabel': {'Confidence': 81.43177795410156, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 81.43177795410156
# Parent category:
# Timestamp: 8008
#
# {'Timestamp': 8508, 'ModerationLabel': {'Confidence': 88.81182098388672, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 88.81182098388672
# Parent category: Swimwear or Underwear
# Timestamp: 8508
#
# {'Timestamp': 8508, 'ModerationLabel': {'Confidence': 91.87299346923828, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 91.87299346923828
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 8508
#
# {'Timestamp': 8508, 'ModerationLabel': {'Confidence': 91.87299346923828, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 91.87299346923828
# Parent category:
# Timestamp: 8508
#
# {'Timestamp': 8508, 'ModerationLabel': {'Confidence': 91.87299346923828, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 91.87299346923828
# Parent category: Non-Explicit Nudity
# Timestamp: 8508
#
# {'Timestamp': 8508, 'ModerationLabel': {'Confidence': 88.81182098388672, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 88.81182098388672
# Parent category:
# Timestamp: 8508
#
# {'Timestamp': 9009, 'ModerationLabel': {'Confidence': 92.1242904663086, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 92.1242904663086
# Parent category: Swimwear or Underwear
# Timestamp: 9009
#
# {'Timestamp': 9009, 'ModerationLabel': {'Confidence': 94.00203704833984, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 94.00203704833984
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 9009
#
# {'Timestamp': 9009, 'ModerationLabel': {'Confidence': 94.00203704833984, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 94.00203704833984
# Parent category:
# Timestamp: 9009
#
# {'Timestamp': 9009, 'ModerationLabel': {'Confidence': 94.00203704833984, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 94.00203704833984
# Parent category: Non-Explicit Nudity
# Timestamp: 9009
#
# {'Timestamp': 9009, 'ModerationLabel': {'Confidence': 92.1242904663086, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 92.1242904663086
# Parent category:
# Timestamp: 9009
#
# {'Timestamp': 9509, 'ModerationLabel': {'Confidence': 91.41194152832031, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 91.41194152832031
# Parent category: Swimwear or Underwear
# Timestamp: 9509
#
# {'Timestamp': 9509, 'ModerationLabel': {'Confidence': 94.70294189453125, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 94.70294189453125
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 9509
#
# {'Timestamp': 9509, 'ModerationLabel': {'Confidence': 94.70294189453125, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 94.70294189453125
# Parent category:
# Timestamp: 9509
#
# {'Timestamp': 9509, 'ModerationLabel': {'Confidence': 94.70294189453125, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 94.70294189453125
# Parent category: Non-Explicit Nudity
# Timestamp: 9509
#
# {'Timestamp': 9509, 'ModerationLabel': {'Confidence': 91.41194152832031, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 91.41194152832031
# Parent category:
# Timestamp: 9509
#
# {'Timestamp': 10010, 'ModerationLabel': {'Confidence': 87.45435333251953, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 87.45435333251953
# Parent category: Swimwear or Underwear
# Timestamp: 10010
#
# {'Timestamp': 10010, 'ModerationLabel': {'Confidence': 90.20252227783203, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 90.20252227783203
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 10010
#
# {'Timestamp': 10010, 'ModerationLabel': {'Confidence': 90.20252227783203, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 90.20252227783203
# Parent category:
# Timestamp: 10010
#
# {'Timestamp': 10010, 'ModerationLabel': {'Confidence': 90.20252227783203, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 90.20252227783203
# Parent category: Non-Explicit Nudity
# Timestamp: 10010
#
# {'Timestamp': 10010, 'ModerationLabel': {'Confidence': 87.4545669555664, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 87.4545669555664
# Parent category:
# Timestamp: 10010
#
# {'Timestamp': 10510, 'ModerationLabel': {'Confidence': 79.57869720458984, 'Name': 'Female Swimwear or Underwear', 'ParentName': 'Swimwear or Underwear', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Female Swimwear or Underwear
# Confidence: 79.57869720458984
# Parent category: Swimwear or Underwear
# Timestamp: 10510
#
# {'Timestamp': 10510, 'ModerationLabel': {'Confidence': 81.17757415771484, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 81.17757415771484
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 10510
#
# {'Timestamp': 10510, 'ModerationLabel': {'Confidence': 81.17757415771484, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 81.17757415771484
# Parent category:
# Timestamp: 10510
#
# {'Timestamp': 10510, 'ModerationLabel': {'Confidence': 81.17321014404297, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 81.17321014404297
# Parent category: Non-Explicit Nudity
# Timestamp: 10510
#
# {'Timestamp': 10510, 'ModerationLabel': {'Confidence': 79.579345703125, 'Name': 'Swimwear or Underwear', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Swimwear or Underwear
# Confidence: 79.579345703125
# Parent category:
# Timestamp: 10510
#
# {'Timestamp': 15015, 'ModerationLabel': {'Confidence': 83.99671936035156, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 83.99671936035156
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 15015
#
# {'Timestamp': 15015, 'ModerationLabel': {'Confidence': 83.99671936035156, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 83.99671936035156
# Parent category:
# Timestamp: 15015
#
# {'Timestamp': 15015, 'ModerationLabel': {'Confidence': 83.99671936035156, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 83.99671936035156
# Parent category: Non-Explicit Nudity
# Timestamp: 15015
#
# {'Timestamp': 15515, 'ModerationLabel': {'Confidence': 94.94306945800781, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 94.94306945800781
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 15515
#
# {'Timestamp': 15515, 'ModerationLabel': {'Confidence': 94.94306945800781, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 94.94306945800781
# Parent category:
# Timestamp: 15515
#
# {'Timestamp': 15515, 'ModerationLabel': {'Confidence': 94.94306945800781, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 94.94306945800781
# Parent category: Non-Explicit Nudity
# Timestamp: 15515
#
# {'Timestamp': 16016, 'ModerationLabel': {'Confidence': 99.57775115966797, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 99.57775115966797
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 16016
#
# {'Timestamp': 16016, 'ModerationLabel': {'Confidence': 99.57775115966797, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 99.57775115966797
# Parent category:
# Timestamp: 16016
#
# {'Timestamp': 16016, 'ModerationLabel': {'Confidence': 99.57775115966797, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 99.57775115966797
# Parent category: Non-Explicit Nudity
# Timestamp: 16016
#
# {'Timestamp': 16516, 'ModerationLabel': {'Confidence': 99.05270385742188, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 99.05270385742188
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 16516
#
# {'Timestamp': 16516, 'ModerationLabel': {'Confidence': 99.05270385742188, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 99.05270385742188
# Parent category:
# Timestamp: 16516
#
# {'Timestamp': 16516, 'ModerationLabel': {'Confidence': 99.05270385742188, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 99.05270385742188
# Parent category: Non-Explicit Nudity
# Timestamp: 16516
#
# {'Timestamp': 17017, 'ModerationLabel': {'Confidence': 94.56775665283203, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 94.56775665283203
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 17017
#
# {'Timestamp': 17017, 'ModerationLabel': {'Confidence': 94.56775665283203, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 94.56775665283203
# Parent category:
# Timestamp: 17017
#
# {'Timestamp': 17017, 'ModerationLabel': {'Confidence': 94.56166076660156, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 94.56166076660156
# Parent category: Non-Explicit Nudity
# Timestamp: 17017
#
# {'Timestamp': 17517, 'ModerationLabel': {'Confidence': 84.08818054199219, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 84.08818054199219
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 17517
#
# {'Timestamp': 17517, 'ModerationLabel': {'Confidence': 84.08818054199219, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 84.08818054199219
# Parent category:
# Timestamp: 17517
#
# {'Timestamp': 17517, 'ModerationLabel': {'Confidence': 84.07598876953125, 'Name': 'Partially Exposed Female Breast', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Partially Exposed Female Breast
# Confidence: 84.07598876953125
# Parent category: Non-Explicit Nudity
# Timestamp: 17517
#
# {'Timestamp': 25525, 'ModerationLabel': {'Confidence': 72.99234771728516, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 72.99234771728516
# Parent category:
# Timestamp: 25525
#
# {'Timestamp': 25525, 'ModerationLabel': {'Confidence': 71.00911712646484, 'Name': 'Obstructed Female Nipple', 'ParentName': 'Obstructed Intimate Parts', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Obstructed Female Nipple
# Confidence: 71.00911712646484
# Parent category: Obstructed Intimate Parts
# Timestamp: 25525
#
# {'Timestamp': 25525, 'ModerationLabel': {'Confidence': 71.00911712646484, 'Name': 'Obstructed Intimate Parts', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Obstructed Intimate Parts
# Confidence: 71.00911712646484
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 25525
#
# done

# %%
import pandas
import boto3
import time

session = boto3.Session()
client = session.client('rekognition')

#I am creating an empty dictionary here
output = {"celebrity":[], "furtherinfo":[]}

videoID_list = []

#I am creating a list her that will contain duplicate celebrity names extracted from the video
celebritylist =[]

#This is for the further information data
furtherinfolist = []

response = client.start_content_moderation(
    Video={
        "S3Object": {
            "Bucket": "bpbucket24"
            , "Name": "Won_1.mp4"
        }
    }
)

job_id = response["JobId"]
print(f"{job_id=}")

while True:
    response = client.get_content_moderation(JobId=job_id)
    print(f"{response['JobStatus']=}")
    if response['JobStatus'] == 'IN_PROGRESS':
        print("time.sleep(10)")
        time.sleep(10)
    else:
        break

next_token = None

while True:
    if next_token is None:
        response = client.get_content_moderation(JobId=job_id)
    else:
        response = client.get_content_moderation(JobId=job_id, NextToken=next_token)
    next_token = response.get("NextToken")
    if next_token is None:
        break

#print(response['ModerationLabels'])
if len(response['ModerationLabels']) == 0:
    print("No Problem Detected")
else:
    for contentModerationDetection in response['ModerationLabels']:
        print(contentModerationDetection)        
        print('Label: ' + str(contentModerationDetection['ModerationLabel']['Name']))
        print('Confidence: ' + str(contentModerationDetection['ModerationLabel']['Confidence']))
        print('Parent category: ' + str(contentModerationDetection['ModerationLabel']['ParentName']))
        print('Timestamp: ' + str(contentModerationDetection['Timestamp']))
        print()
print("done")
# Out:
# job_id='84d8ebe88a48a8601f7d174745f5b310df64d6afbabff1dae7656e52faa2c942'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# {'Timestamp': 516, 'ModerationLabel': {'Confidence': 62.72012710571289, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 62.72012710571289
# Parent category:
# Timestamp: 516
#
# {'Timestamp': 516, 'ModerationLabel': {'Confidence': 62.72012710571289, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 62.72012710571289
# Parent category: Explicit
# Timestamp: 516
#
# {'Timestamp': 516, 'ModerationLabel': {'Confidence': 62.72012710571289, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 62.72012710571289
# Parent category: Explicit Nudity
# Timestamp: 516
#
# {'Timestamp': 516, 'ModerationLabel': {'Confidence': 78.02902221679688, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 78.02902221679688
# Parent category: Non-Explicit Nudity
# Timestamp: 516
#
# {'Timestamp': 516, 'ModerationLabel': {'Confidence': 78.02902221679688, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 78.02902221679688
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 516
#
# {'Timestamp': 516, 'ModerationLabel': {'Confidence': 78.02902221679688, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 78.02902221679688
# Parent category:
# Timestamp: 516
#
# {'Timestamp': 1033, 'ModerationLabel': {'Confidence': 66.79689025878906, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 66.79689025878906
# Parent category: Non-Explicit Nudity
# Timestamp: 1033
#
# {'Timestamp': 1033, 'ModerationLabel': {'Confidence': 66.79689025878906, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 66.79689025878906
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 1033
#
# {'Timestamp': 1033, 'ModerationLabel': {'Confidence': 66.79689025878906, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 66.79689025878906
# Parent category:
# Timestamp: 1033
#
# {'Timestamp': 2033, 'ModerationLabel': {'Confidence': 72.7978744506836, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 72.7978744506836
# Parent category: Non-Explicit Nudity
# Timestamp: 2033
#
# {'Timestamp': 2033, 'ModerationLabel': {'Confidence': 72.7978744506836, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 72.7978744506836
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 2033
#
# {'Timestamp': 2033, 'ModerationLabel': {'Confidence': 72.7978744506836, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 72.7978744506836
# Parent category:
# Timestamp: 2033
#
# {'Timestamp': 2533, 'ModerationLabel': {'Confidence': 82.88597869873047, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 82.88597869873047
# Parent category: Non-Explicit Nudity
# Timestamp: 2533
#
# {'Timestamp': 2533, 'ModerationLabel': {'Confidence': 82.88597869873047, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 82.88597869873047
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 2533
#
# {'Timestamp': 2533, 'ModerationLabel': {'Confidence': 82.88597869873047, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 82.88597869873047
# Parent category:
# Timestamp: 2533
#
# {'Timestamp': 3533, 'ModerationLabel': {'Confidence': 80.86644744873047, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 80.86644744873047
# Parent category:
# Timestamp: 3533
#
# {'Timestamp': 3533, 'ModerationLabel': {'Confidence': 80.86644744873047, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 80.86644744873047
# Parent category: Explicit
# Timestamp: 3533
#
# {'Timestamp': 3533, 'ModerationLabel': {'Confidence': 80.86644744873047, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 80.86644744873047
# Parent category: Explicit Nudity
# Timestamp: 3533
#
# {'Timestamp': 4033, 'ModerationLabel': {'Confidence': 81.99070739746094, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 81.99070739746094
# Parent category:
# Timestamp: 4033
#
# {'Timestamp': 4033, 'ModerationLabel': {'Confidence': 81.99070739746094, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 81.99070739746094
# Parent category: Explicit
# Timestamp: 4033
#
# {'Timestamp': 4033, 'ModerationLabel': {'Confidence': 81.99070739746094, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 81.99070739746094
# Parent category: Explicit Nudity
# Timestamp: 4033
#
# {'Timestamp': 4033, 'ModerationLabel': {'Confidence': 74.34125518798828, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 74.34125518798828
# Parent category: Non-Explicit Nudity
# Timestamp: 4033
#
# {'Timestamp': 4033, 'ModerationLabel': {'Confidence': 74.34125518798828, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 74.34125518798828
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 4033
#
# {'Timestamp': 4033, 'ModerationLabel': {'Confidence': 74.34125518798828, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 74.34125518798828
# Parent category:
# Timestamp: 4033
#
# {'Timestamp': 5000, 'ModerationLabel': {'Confidence': 82.98663330078125, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 82.98663330078125
# Parent category:
# Timestamp: 5000
#
# {'Timestamp': 5000, 'ModerationLabel': {'Confidence': 82.98663330078125, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 82.98663330078125
# Parent category: Explicit
# Timestamp: 5000
#
# {'Timestamp': 5000, 'ModerationLabel': {'Confidence': 82.98663330078125, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 82.98663330078125
# Parent category: Explicit Nudity
# Timestamp: 5000
#
# {'Timestamp': 6016, 'ModerationLabel': {'Confidence': 86.81987762451172, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 86.81987762451172
# Parent category:
# Timestamp: 6016
#
# {'Timestamp': 6016, 'ModerationLabel': {'Confidence': 86.81987762451172, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 86.81987762451172
# Parent category: Explicit
# Timestamp: 6016
#
# {'Timestamp': 6016, 'ModerationLabel': {'Confidence': 68.7689437866211, 'Name': 'Explicit Sexual Activity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Sexual Activity
# Confidence: 68.7689437866211
# Parent category: Explicit
# Timestamp: 6016
#
# {'Timestamp': 6016, 'ModerationLabel': {'Confidence': 86.81987762451172, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 86.81987762451172
# Parent category: Explicit Nudity
# Timestamp: 6016
#
# {'Timestamp': 6516, 'ModerationLabel': {'Confidence': 85.5236587524414, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 85.5236587524414
# Parent category:
# Timestamp: 6516
#
# {'Timestamp': 6516, 'ModerationLabel': {'Confidence': 85.5236587524414, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 85.5236587524414
# Parent category: Explicit
# Timestamp: 6516
#
# {'Timestamp': 6516, 'ModerationLabel': {'Confidence': 85.5236587524414, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 85.5236587524414
# Parent category: Explicit Nudity
# Timestamp: 6516
#
# {'Timestamp': 7000, 'ModerationLabel': {'Confidence': 83.03336334228516, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 83.03336334228516
# Parent category: Non-Explicit Nudity
# Timestamp: 7000
#
# {'Timestamp': 7000, 'ModerationLabel': {'Confidence': 83.03336334228516, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 83.03336334228516
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 7000
#
# {'Timestamp': 7000, 'ModerationLabel': {'Confidence': 83.03336334228516, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 83.03336334228516
# Parent category:
# Timestamp: 7000
#
# {'Timestamp': 7500, 'ModerationLabel': {'Confidence': 84.99512481689453, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 84.99512481689453
# Parent category: Non-Explicit Nudity
# Timestamp: 7500
#
# {'Timestamp': 7500, 'ModerationLabel': {'Confidence': 84.99512481689453, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 84.99512481689453
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 7500
#
# {'Timestamp': 7500, 'ModerationLabel': {'Confidence': 84.99512481689453, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 84.99512481689453
# Parent category:
# Timestamp: 7500
#
# {'Timestamp': 8016, 'ModerationLabel': {'Confidence': 58.005462646484375, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 58.005462646484375
# Parent category:
# Timestamp: 8016
#
# {'Timestamp': 8016, 'ModerationLabel': {'Confidence': 57.564674377441406, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 57.564674377441406
# Parent category: Explicit
# Timestamp: 8016
#
# {'Timestamp': 8016, 'ModerationLabel': {'Confidence': 57.564674377441406, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 57.564674377441406
# Parent category: Explicit Nudity
# Timestamp: 8016
#
# {'Timestamp': 8016, 'ModerationLabel': {'Confidence': 86.28630065917969, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 86.28630065917969
# Parent category: Non-Explicit Nudity
# Timestamp: 8016
#
# {'Timestamp': 8016, 'ModerationLabel': {'Confidence': 86.28630065917969, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 86.28630065917969
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 8016
#
# {'Timestamp': 8016, 'ModerationLabel': {'Confidence': 86.28630065917969, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 86.28630065917969
# Parent category:
# Timestamp: 8016
#
# {'Timestamp': 8516, 'ModerationLabel': {'Confidence': 86.46864318847656, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 86.46864318847656
# Parent category:
# Timestamp: 8516
#
# {'Timestamp': 8516, 'ModerationLabel': {'Confidence': 82.94231414794922, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 82.94231414794922
# Parent category: Explicit
# Timestamp: 8516
#
# {'Timestamp': 8516, 'ModerationLabel': {'Confidence': 74.90249633789062, 'Name': 'Explicit Sexual Activity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Sexual Activity
# Confidence: 74.90249633789062
# Parent category: Explicit
# Timestamp: 8516
#
# {'Timestamp': 8516, 'ModerationLabel': {'Confidence': 82.94231414794922, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 82.94231414794922
# Parent category: Explicit Nudity
# Timestamp: 8516
#
# {'Timestamp': 9016, 'ModerationLabel': {'Confidence': 87.34794616699219, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 87.34794616699219
# Parent category:
# Timestamp: 9016
#
# {'Timestamp': 9016, 'ModerationLabel': {'Confidence': 86.90715026855469, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 86.90715026855469
# Parent category: Explicit
# Timestamp: 9016
#
# {'Timestamp': 9016, 'ModerationLabel': {'Confidence': 86.90715026855469, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 86.90715026855469
# Parent category: Explicit Nudity
# Timestamp: 9016
#
# {'Timestamp': 9016, 'ModerationLabel': {'Confidence': 82.70381927490234, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 82.70381927490234
# Parent category: Non-Explicit Nudity
# Timestamp: 9016
#
# {'Timestamp': 9016, 'ModerationLabel': {'Confidence': 82.70381927490234, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 82.70381927490234
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 9016
#
# {'Timestamp': 9016, 'ModerationLabel': {'Confidence': 82.70381927490234, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 82.70381927490234
# Parent category:
# Timestamp: 9016
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 58.484622955322266, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 58.484622955322266
# Parent category:
# Timestamp: 9500
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 58.264225006103516, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 58.264225006103516
# Parent category: Explicit
# Timestamp: 9500
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 58.264225006103516, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 58.264225006103516
# Parent category: Explicit Nudity
# Timestamp: 9500
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 84.36577606201172, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 84.36577606201172
# Parent category: Non-Explicit Nudity
# Timestamp: 9500
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 84.36577606201172, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 84.36577606201172
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 9500
#
# {'Timestamp': 9500, 'ModerationLabel': {'Confidence': 84.36577606201172, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 84.36577606201172
# Parent category:
# Timestamp: 9500
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 85.06574249267578, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 85.06574249267578
# Parent category:
# Timestamp: 10000
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 85.06574249267578, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 85.06574249267578
# Parent category: Explicit
# Timestamp: 10000
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 70.06451416015625, 'Name': 'Explicit Sexual Activity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Sexual Activity
# Confidence: 70.06451416015625
# Parent category: Explicit
# Timestamp: 10000
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 85.06574249267578, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 85.06574249267578
# Parent category: Explicit Nudity
# Timestamp: 10000
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 59.69729232788086, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 59.69729232788086
# Parent category: Non-Explicit Nudity
# Timestamp: 10000
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 59.69729232788086, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 59.69729232788086
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 10000
#
# {'Timestamp': 10000, 'ModerationLabel': {'Confidence': 59.69729232788086, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 59.69729232788086
# Parent category:
# Timestamp: 10000
#
# {'Timestamp': 10516, 'ModerationLabel': {'Confidence': 81.98016357421875, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 81.98016357421875
# Parent category:
# Timestamp: 10516
#
# {'Timestamp': 10516, 'ModerationLabel': {'Confidence': 81.98016357421875, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 81.98016357421875
# Parent category: Explicit
# Timestamp: 10516
#
# {'Timestamp': 10516, 'ModerationLabel': {'Confidence': 81.98016357421875, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 81.98016357421875
# Parent category: Explicit Nudity
# Timestamp: 10516
#
# {'Timestamp': 10516, 'ModerationLabel': {'Confidence': 87.96609497070312, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 87.96609497070312
# Parent category: Non-Explicit Nudity
# Timestamp: 10516
#
# {'Timestamp': 10516, 'ModerationLabel': {'Confidence': 87.96609497070312, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 87.96609497070312
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 10516
#
# {'Timestamp': 10516, 'ModerationLabel': {'Confidence': 87.96609497070312, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 87.96609497070312
# Parent category:
# Timestamp: 10516
#
# {'Timestamp': 11016, 'ModerationLabel': {'Confidence': 85.89533233642578, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 85.89533233642578
# Parent category: Non-Explicit Nudity
# Timestamp: 11016
#
# {'Timestamp': 11016, 'ModerationLabel': {'Confidence': 85.89533233642578, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 85.89533233642578
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 11016
#
# {'Timestamp': 11016, 'ModerationLabel': {'Confidence': 85.89533233642578, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 85.89533233642578
# Parent category:
# Timestamp: 11016
#
# {'Timestamp': 11516, 'ModerationLabel': {'Confidence': 77.83151245117188, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 77.83151245117188
# Parent category:
# Timestamp: 11516
#
# {'Timestamp': 11516, 'ModerationLabel': {'Confidence': 77.83151245117188, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 77.83151245117188
# Parent category: Explicit
# Timestamp: 11516
#
# {'Timestamp': 11516, 'ModerationLabel': {'Confidence': 77.83151245117188, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 77.83151245117188
# Parent category: Explicit Nudity
# Timestamp: 11516
#
# {'Timestamp': 11516, 'ModerationLabel': {'Confidence': 83.84725189208984, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 83.84725189208984
# Parent category: Non-Explicit Nudity
# Timestamp: 11516
#
# {'Timestamp': 11516, 'ModerationLabel': {'Confidence': 83.84725189208984, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 83.84725189208984
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 11516
#
# {'Timestamp': 11516, 'ModerationLabel': {'Confidence': 83.84725189208984, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 83.84725189208984
# Parent category:
# Timestamp: 11516
#
# {'Timestamp': 12500, 'ModerationLabel': {'Confidence': 87.89796447753906, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 87.89796447753906
# Parent category:
# Timestamp: 12500
#
# {'Timestamp': 12500, 'ModerationLabel': {'Confidence': 87.89796447753906, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 87.89796447753906
# Parent category: Explicit
# Timestamp: 12500
#
# {'Timestamp': 12500, 'ModerationLabel': {'Confidence': 69.81668853759766, 'Name': 'Explicit Sexual Activity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Sexual Activity
# Confidence: 69.81668853759766
# Parent category: Explicit
# Timestamp: 12500
#
# {'Timestamp': 12500, 'ModerationLabel': {'Confidence': 87.89796447753906, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 87.89796447753906
# Parent category: Explicit Nudity
# Timestamp: 12500
#
# {'Timestamp': 13016, 'ModerationLabel': {'Confidence': 91.23538208007812, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 91.23538208007812
# Parent category:
# Timestamp: 13016
#
# {'Timestamp': 13016, 'ModerationLabel': {'Confidence': 91.23538208007812, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 91.23538208007812
# Parent category: Explicit
# Timestamp: 13016
#
# {'Timestamp': 13016, 'ModerationLabel': {'Confidence': 91.23538208007812, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 91.23538208007812
# Parent category: Explicit Nudity
# Timestamp: 13016
#
# {'Timestamp': 13016, 'ModerationLabel': {'Confidence': 82.00199890136719, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 82.00199890136719
# Parent category: Non-Explicit Nudity
# Timestamp: 13016
#
# {'Timestamp': 13016, 'ModerationLabel': {'Confidence': 82.00199890136719, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 82.00199890136719
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 13016
#
# {'Timestamp': 13016, 'ModerationLabel': {'Confidence': 82.00199890136719, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 82.00199890136719
# Parent category:
# Timestamp: 13016
#
# {'Timestamp': 13516, 'ModerationLabel': {'Confidence': 93.18816375732422, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 93.18816375732422
# Parent category:
# Timestamp: 13516
#
# {'Timestamp': 13516, 'ModerationLabel': {'Confidence': 93.18816375732422, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 93.18816375732422
# Parent category: Explicit
# Timestamp: 13516
#
# {'Timestamp': 13516, 'ModerationLabel': {'Confidence': 93.18816375732422, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 93.18816375732422
# Parent category: Explicit Nudity
# Timestamp: 13516
#
# {'Timestamp': 13516, 'ModerationLabel': {'Confidence': 90.85870361328125, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 90.85870361328125
# Parent category: Non-Explicit Nudity
# Timestamp: 13516
#
# {'Timestamp': 13516, 'ModerationLabel': {'Confidence': 90.85870361328125, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 90.85870361328125
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 13516
#
# {'Timestamp': 13516, 'ModerationLabel': {'Confidence': 90.85870361328125, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 90.85870361328125
# Parent category:
# Timestamp: 13516
#
# {'Timestamp': 14016, 'ModerationLabel': {'Confidence': 93.24825286865234, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 93.24825286865234
# Parent category:
# Timestamp: 14016
#
# {'Timestamp': 14016, 'ModerationLabel': {'Confidence': 93.24825286865234, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 93.24825286865234
# Parent category: Explicit
# Timestamp: 14016
#
# {'Timestamp': 14016, 'ModerationLabel': {'Confidence': 93.24825286865234, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 93.24825286865234
# Parent category: Explicit Nudity
# Timestamp: 14016
#
# {'Timestamp': 14016, 'ModerationLabel': {'Confidence': 89.714599609375, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 89.714599609375
# Parent category: Non-Explicit Nudity
# Timestamp: 14016
#
# {'Timestamp': 14016, 'ModerationLabel': {'Confidence': 89.714599609375, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 89.714599609375
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 14016
#
# {'Timestamp': 14016, 'ModerationLabel': {'Confidence': 89.714599609375, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 89.714599609375
# Parent category:
# Timestamp: 14016
#
# {'Timestamp': 14516, 'ModerationLabel': {'Confidence': 93.84309387207031, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 93.84309387207031
# Parent category:
# Timestamp: 14516
#
# {'Timestamp': 14516, 'ModerationLabel': {'Confidence': 93.84309387207031, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 93.84309387207031
# Parent category: Explicit
# Timestamp: 14516
#
# {'Timestamp': 14516, 'ModerationLabel': {'Confidence': 93.84309387207031, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 93.84309387207031
# Parent category: Explicit Nudity
# Timestamp: 14516
#
# {'Timestamp': 14516, 'ModerationLabel': {'Confidence': 84.61295318603516, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 84.61295318603516
# Parent category: Non-Explicit Nudity
# Timestamp: 14516
#
# {'Timestamp': 14516, 'ModerationLabel': {'Confidence': 84.61295318603516, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 84.61295318603516
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 14516
#
# {'Timestamp': 14516, 'ModerationLabel': {'Confidence': 84.61295318603516, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 84.61295318603516
# Parent category:
# Timestamp: 14516
#
# {'Timestamp': 15016, 'ModerationLabel': {'Confidence': 97.3567886352539, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 97.3567886352539
# Parent category:
# Timestamp: 15016
#
# {'Timestamp': 15016, 'ModerationLabel': {'Confidence': 97.3567886352539, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 97.3567886352539
# Parent category: Explicit
# Timestamp: 15016
#
# {'Timestamp': 15016, 'ModerationLabel': {'Confidence': 77.32652282714844, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 77.32652282714844
# Parent category: Explicit Nudity
# Timestamp: 15016
#
# {'Timestamp': 15016, 'ModerationLabel': {'Confidence': 97.3567886352539, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 97.3567886352539
# Parent category: Explicit Nudity
# Timestamp: 15016
#
# {'Timestamp': 15500, 'ModerationLabel': {'Confidence': 95.71590423583984, 'Name': 'Explicit', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Explicit
# Confidence: 95.71590423583984
# Parent category:
# Timestamp: 15500
#
# {'Timestamp': 15500, 'ModerationLabel': {'Confidence': 95.71590423583984, 'Name': 'Explicit Nudity', 'ParentName': 'Explicit', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Explicit Nudity
# Confidence: 95.71590423583984
# Parent category: Explicit
# Timestamp: 15500
#
# {'Timestamp': 15500, 'ModerationLabel': {'Confidence': 85.3186264038086, 'Name': 'Exposed Female Genitalia', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Genitalia
# Confidence: 85.3186264038086
# Parent category: Explicit Nudity
# Timestamp: 15500
#
# {'Timestamp': 15500, 'ModerationLabel': {'Confidence': 95.71590423583984, 'Name': 'Exposed Female Nipple', 'ParentName': 'Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Female Nipple
# Confidence: 95.71590423583984
# Parent category: Explicit Nudity
# Timestamp: 15500
#
# {'Timestamp': 15500, 'ModerationLabel': {'Confidence': 72.93961334228516, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 72.93961334228516
# Parent category: Non-Explicit Nudity
# Timestamp: 15500
#
# {'Timestamp': 15500, 'ModerationLabel': {'Confidence': 72.93961334228516, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 72.93961334228516
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 15500
#
# {'Timestamp': 15500, 'ModerationLabel': {'Confidence': 72.93961334228516, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 72.93961334228516
# Parent category:
# Timestamp: 15500
#
# done

# %%
import pandas
import boto3
import time

session = boto3.Session()
client = session.client('rekognition')

#I am creating an empty dictionary here
output = {"celebrity":[], "furtherinfo":[]}

videoID_list = []

#I am creating a list her that will contain duplicate celebrity names extracted from the video
celebritylist =[]

#This is for the further information data
furtherinfolist = []

response = client.start_content_moderation(
    Video={
        "S3Object": {
            "Bucket": "bpbucket24"
            , "Name": "Won_2.mp4"
        }
    }
)

job_id = response["JobId"]
print(f"{job_id=}")

while True:
    response = client.get_content_moderation(JobId=job_id)
    print(f"{response['JobStatus']=}")
    if response['JobStatus'] == 'IN_PROGRESS':
        print("time.sleep(10)")
        time.sleep(10)
    else:
        break

next_token = None

while True:
    if next_token is None:
        response = client.get_content_moderation(JobId=job_id)
    else:
        response = client.get_content_moderation(JobId=job_id, NextToken=next_token)
    next_token = response.get("NextToken")
    if next_token is None:
        break

#print(response['ModerationLabels'])
if len(response['ModerationLabels']) == 0:
    print("No Problem Detected")
else:
    for contentModerationDetection in response['ModerationLabels']:
        print(contentModerationDetection)        
        print('Label: ' + str(contentModerationDetection['ModerationLabel']['Name']))
        print('Confidence: ' + str(contentModerationDetection['ModerationLabel']['Confidence']))
        print('Parent category: ' + str(contentModerationDetection['ModerationLabel']['ParentName']))
        print('Timestamp: ' + str(contentModerationDetection['Timestamp']))
        print()
print("done")
# Out:
# job_id='85be678e91a59d2e60f7ecab3b49392a65ff69e19d56deb502a34a9fb99998cc'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# No Problem Detected
# done

# %%
import pandas
import boto3
import time

session = boto3.Session()
client = session.client('rekognition')

#I am creating an empty dictionary here
output = {"celebrity":[], "furtherinfo":[]}

videoID_list = []

#I am creating a list her that will contain duplicate celebrity names extracted from the video
celebritylist =[]

#This is for the further information data
furtherinfolist = []

response = client.start_content_moderation(
    Video={
        "S3Object": {
            "Bucket": "bpbucket24"
            , "Name": "Won_3.mp4"
        }
    }
)

job_id = response["JobId"]
print(f"{job_id=}")

while True:
    response = client.get_content_moderation(JobId=job_id)
    print(f"{response['JobStatus']=}")
    if response['JobStatus'] == 'IN_PROGRESS':
        print("time.sleep(10)")
        time.sleep(10)
    else:
        break

next_token = None

while True:
    if next_token is None:
        response = client.get_content_moderation(JobId=job_id)
    else:
        response = client.get_content_moderation(JobId=job_id, NextToken=next_token)
    next_token = response.get("NextToken")
    if next_token is None:
        break

#print(response['ModerationLabels'])
if len(response['ModerationLabels']) == 0:
    print("No Problem Detected")
else:
    for contentModerationDetection in response['ModerationLabels']:
        print(contentModerationDetection)        
        print('Label: ' + str(contentModerationDetection['ModerationLabel']['Name']))
        print('Confidence: ' + str(contentModerationDetection['ModerationLabel']['Confidence']))
        print('Parent category: ' + str(contentModerationDetection['ModerationLabel']['ParentName']))
        print('Timestamp: ' + str(contentModerationDetection['Timestamp']))
        print()
print("done")
# Out:
# job_id='d4410439b79a629092df04b392a3ea0ce8010d0b64294b2f8d086f8576a4a8ec'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# No Problem Detected
# done

# %%
import pandas
import boto3
import time

session = boto3.Session()
client = session.client('rekognition')

#I am creating an empty dictionary here
output = {"celebrity":[], "furtherinfo":[]}

videoID_list = []

#I am creating a list her that will contain duplicate celebrity names extracted from the video
celebritylist =[]

#This is for the further information data
furtherinfolist = []

response = client.start_content_moderation(
    Video={
        "S3Object": {
            "Bucket": "bpbucket24"
            , "Name": "Won_4.mp4"
        }
    }
)

job_id = response["JobId"]
print(f"{job_id=}")

while True:
    response = client.get_content_moderation(JobId=job_id)
    print(f"{response['JobStatus']=}")
    if response['JobStatus'] == 'IN_PROGRESS':
        print("time.sleep(10)")
        time.sleep(10)
    else:
        break

next_token = None

while True:
    if next_token is None:
        response = client.get_content_moderation(JobId=job_id)
    else:
        response = client.get_content_moderation(JobId=job_id, NextToken=next_token)
    next_token = response.get("NextToken")
    if next_token is None:
        break

#print(response['ModerationLabels'])
if len(response['ModerationLabels']) == 0:
    print("No Problem Detected")
else:
    for contentModerationDetection in response['ModerationLabels']:
        print(contentModerationDetection)        
        print('Label: ' + str(contentModerationDetection['ModerationLabel']['Name']))
        print('Confidence: ' + str(contentModerationDetection['ModerationLabel']['Confidence']))
        print('Parent category: ' + str(contentModerationDetection['ModerationLabel']['ParentName']))
        print('Timestamp: ' + str(contentModerationDetection['Timestamp']))
        print()
print("done")
# Out:
# job_id='d9995b27883dacaa21ecbef3cb8daff1441bae1156e78b2ee4b696bd50ee34c8'
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='IN_PROGRESS'
# time.sleep(10)
# response['JobStatus']='SUCCEEDED'
# {'Timestamp': 4500, 'ModerationLabel': {'Confidence': 85.9253921508789, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 85.9253921508789
# Parent category: Non-Explicit Nudity
# Timestamp: 4500
#
# {'Timestamp': 4500, 'ModerationLabel': {'Confidence': 85.9253921508789, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 85.9253921508789
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 4500
#
# {'Timestamp': 4500, 'ModerationLabel': {'Confidence': 85.92549896240234, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 85.92549896240234
# Parent category:
# Timestamp: 4500
#
# {'Timestamp': 5000, 'ModerationLabel': {'Confidence': 95.35511779785156, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 95.35511779785156
# Parent category: Non-Explicit Nudity
# Timestamp: 5000
#
# {'Timestamp': 5000, 'ModerationLabel': {'Confidence': 95.35511779785156, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 95.35511779785156
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 5000
#
# {'Timestamp': 5000, 'ModerationLabel': {'Confidence': 95.35516357421875, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 95.35516357421875
# Parent category:
# Timestamp: 5000
#
# {'Timestamp': 5500, 'ModerationLabel': {'Confidence': 99.84736633300781, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 99.84736633300781
# Parent category: Non-Explicit Nudity
# Timestamp: 5500
#
# {'Timestamp': 5500, 'ModerationLabel': {'Confidence': 99.84736633300781, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 99.84736633300781
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 5500
#
# {'Timestamp': 5500, 'ModerationLabel': {'Confidence': 99.84736633300781, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 99.84736633300781
# Parent category:
# Timestamp: 5500
#
# {'Timestamp': 6000, 'ModerationLabel': {'Confidence': 99.86556243896484, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 99.86556243896484
# Parent category: Non-Explicit Nudity
# Timestamp: 6000
#
# {'Timestamp': 6000, 'ModerationLabel': {'Confidence': 99.86556243896484, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 99.86556243896484
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 6000
#
# {'Timestamp': 6000, 'ModerationLabel': {'Confidence': 99.86556243896484, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 99.86556243896484
# Parent category:
# Timestamp: 6000
#
# {'Timestamp': 6500, 'ModerationLabel': {'Confidence': 99.79401397705078, 'Name': 'Exposed Male Nipple', 'ParentName': 'Non-Explicit Nudity', 'TaxonomyLevel': 3}, 'ContentTypes': []}
# Label: Exposed Male Nipple
# Confidence: 99.79401397705078
# Parent category: Non-Explicit Nudity
# Timestamp: 6500
#
# {'Timestamp': 6500, 'ModerationLabel': {'Confidence': 99.79401397705078, 'Name': 'Non-Explicit Nudity', 'ParentName': 'Non-Explicit Nudity of Intimate parts and Kissing', 'TaxonomyLevel': 2}, 'ContentTypes': []}
# Label: Non-Explicit Nudity
# Confidence: 99.79401397705078
# Parent category: Non-Explicit Nudity of Intimate parts and Kissing
# Timestamp: 6500
#
# {'Timestamp': 6500, 'ModerationLabel': {'Confidence': 99.79401397705078, 'Name': 'Non-Explicit Nudity of Intimate parts and Kissing', 'ParentName': '', 'TaxonomyLevel': 1}, 'ContentTypes': []}
# Label: Non-Explicit Nudity of Intimate parts and Kissing
# Confidence: 99.79401397705078
# Parent category:
# Timestamp: 6500
#
# done

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Question 1
#
# Please see file "textresult"

# %% [markdown]
# ## Question 2
#
# Please see files "labels"

# %% [markdown]
# ## Question 3
#
# #### Sampled video background
# I sampled 3 videos from media influencer Kim Kardashian and 4 videos from K-pop star Wonho. In both of these samples, I chose some that included on-screen texts and suggestive content to review the appropriate algorithm.

# %% [markdown]
# ### Part 1 - Labels

# %%
# !pip install pandas 

import pandas as pd
# Out:
# Requirement already satisfied: pandas in c:\users\brian\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\brian\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\brian\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\brian\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\brian\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
df = pd.read_csv('C:\\Users\\Brian\\Desktop\\Tiktok videos\\labels.csv')

df
# Out:
#     Index         videoname            labels  confidencescores  timestamps
# 0       0  videos/Kim_1.mp4              Male         90.295975       38700
# 1       1  videos/Kim_1.mp4               Man         90.084686       38700
# 2       2  videos/Kim_1.mp4            Person         96.893768       38700
# 3       3  videos/Kim_1.mp4             Adult         97.542847       39200
# 4       4  videos/Kim_1.mp4            Female         92.632309       39200
# 5       5  videos/Kim_1.mp4             Woman         92.632309       39200
# 6       6  videos/Kim_1.mp4         Body Part         90.241516       40200
# 7       7  videos/Kim_1.mp4             Torso         90.221718       40200
# 8       8  videos/Kim_1.mp4          Clothing         92.472626       41200
# 9       9  videos/Kim_2.mp4              Face         92.200043       33766
# 10     10  videos/Kim_2.mp4              Head         92.638039       33766
# 11     11  videos/Kim_2.mp4         Underwear         92.070763       35766
# 12     12  videos/Kim_2.mp4          Swimwear         90.202408       36266
# 13     13  videos/Kim_2.mp4          Lingerie         92.281044       36766
# 14     14  videos/Kim_2.mp4               Bra         94.379921       37266
# 15     15  videos/Kim_2.mp4       Photography         90.337624       38266
# 16     16  videos/Kim_2.mp4          Portrait         90.337624       38266
# 17     17  videos/Kim_2.mp4            Nature         95.354263       48266
# 18     18  videos/Kim_2.mp4          Outdoors         96.160683       48266
# 19     19  videos/Kim_3.mp4       Accessories         97.352791       21521
# 20     20  videos/Kim_3.mp4           Earring         97.296501       21521
# 21     21  videos/Kim_3.mp4           Jewelry         97.296501       21521
# 22     22  videos/Kim_3.mp4            Blonde         97.024689       23523
# 23     23  videos/Kim_3.mp4              Hair         97.024689       23523
# 24     24  videos/Kim_3.mp4           Wedding         93.596275       23523
# 25     25  videos/Won_1.mp4              Baby         90.791580        2533
# 26     26  videos/Won_1.mp4           Fitness         90.121742        4516
# 27     27  videos/Won_1.mp4               Gym         90.121742        4516
# 28     28  videos/Won_1.mp4       Gym Weights         90.121742        4516
# 29     29  videos/Won_1.mp4             Sport         90.121742        4516
# 30     30  videos/Won_1.mp4       Working Out         90.121742        4516
# 31     31  videos/Won_1.mp4       Bench Press         93.140053        5516
# 32     32  videos/Won_2.mp4              Coat         90.613365       59933
# 33     33  videos/Won_2.mp4           Cushion         91.199318       59933
# 34     34  videos/Won_2.mp4        Home Decor         91.516602       59933
# 35     35  videos/Won_2.mp4           Indoors         97.294792       60433
# 36     36  videos/Won_2.mp4   Interior Design         97.294792       60433
# 37     37  videos/Won_2.mp4             Shirt         93.068176       60933
# 38     38  videos/Won_3.mp4               Boy         90.180847        2033
# 39     39  videos/Won_3.mp4          Romantic         90.687042       12500
# 40     40  videos/Won_4.mp4         Performer         99.998283           0
# 41     41  videos/Won_4.mp4  Solo Performance         99.998283           0
# 42     42  videos/Won_5.mp4             Happy         95.042778         520
# 43     43  videos/Won_5.mp4          Laughing         94.896507         520
# 44     44  videos/Won_5.mp4            Eating         91.308601        5520
# 45     45  videos/Won_5.mp4              Food         91.308601        5520

# %%
# Check if any common features among videos. If any common features, value_counts for any listed should be > 1 

df['labels'].value_counts()
# Out:
# Male                1
# Home Decor          1
# Baby                1
# Fitness             1
# Gym                 1
# Gym Weights         1
# Sport               1
# Working Out         1
# Bench Press         1
# Coat                1
# Cushion             1
# Indoors             1
# Man                 1
# Interior Design     1
# Shirt               1
# Boy                 1
# Romantic            1
# Performer           1
# Solo Performance    1
# Happy               1
# Laughing            1
# Eating              1
# Wedding             1
# Hair                1
# Blonde              1
# Jewelry             1
# Person              1
# Adult               1
# Female              1
# Woman               1
# Body Part           1
# Torso               1
# Clothing            1
# Face                1
# Head                1
# Underwear           1
# Swimwear            1
# Lingerie            1
# Bra                 1
# Photography         1
# Portrait            1
# Nature              1
# Outdoors            1
# Accessories         1
# Earring             1
# Food                1
# Name: labels, dtype: int64

# %% [markdown]
# #### Label Review
#
# For labels, the videos do not seem to have any common labels. According to AWS Rekognition, each video is very distinct.

# %% [markdown]
# ### Part 2 - Text

# %%
df = pd.read_csv('C:\\Users\\Brian\\Desktop\\Tiktok videos\\textresult.csv')
df
# Out:
#    Index                                            videoID  \
# 0      1  ['videotext/Kim_1.mp4', 'videotext/Kim_1.mp4',...
# 1      2  ['videotext/Kim_2.mp4', 'videotext/Kim_2.mp4',...
# 2      3  ['videotext/Kim_3.mp4', 'videotext/Kim_3.mp4',...
# 3      4  ['videotext/Won_1.mp4', 'videotext/Won_1.mp4',...
# 4      5  ['videotext/Won_2.mp4', 'videotext/Won_2.mp4',...
# 5      6  ['videotext/Won_3.mp4', 'videotext/Won_3.mp4',...
# 6      7  ['videotext/Won_4.mp4', 'videotext/Won_4.mp4',...
# 7      8  ['videotext/Won_5.mp4', 'videotext/Won_5.mp4',...
#
#                                                 text
# 0  ['TikTok', '@kimkardashian', 'TikTok', '@kimka...
# 1  ['ل TikTok', '@kimkardashian', 'TikTok', '@kim...
# 2  ['ل', 'TikTok', '@kimkardashian', 'ل', 'TikTok...
# 3  ['()', 'TikTok', '@wonhosexy', '()', 'TikTok',...
# 4  ['Wonho demonstrating how', 'he fell between t...
# 5  ['ل TikTok', '@wonhosexy', 'On this day', '11/...
# 6  ['Me walking around with the', 'most unhinged ...
# 7  ['STAGE', 'WONHO', '1:32', 'ل TikTok', '@wonho...

# %%
# Create sets to par down on duplicated texts within each video 
df['sets'] = df['text'].apply(lambda x: set(x.split()))
df
# Out:
#    Index                                            videoID  \
# 0      1  ['videotext/Kim_1.mp4', 'videotext/Kim_1.mp4',...
# 1      2  ['videotext/Kim_2.mp4', 'videotext/Kim_2.mp4',...
# 2      3  ['videotext/Kim_3.mp4', 'videotext/Kim_3.mp4',...
# 3      4  ['videotext/Won_1.mp4', 'videotext/Won_1.mp4',...
# 4      5  ['videotext/Won_2.mp4', 'videotext/Won_2.mp4',...
# 5      6  ['videotext/Won_3.mp4', 'videotext/Won_3.mp4',...
# 6      7  ['videotext/Won_4.mp4', 'videotext/Won_4.mp4',...
# 7      8  ['videotext/Won_5.mp4', 'videotext/Won_5.mp4',...
#
#                                                 text  \
# 0  ['TikTok', '@kimkardashian', 'TikTok', '@kimka...
# 1  ['ل TikTok', '@kimkardashian', 'TikTok', '@kim...
# 2  ['ل', 'TikTok', '@kimkardashian', 'ل', 'TikTok...
# 3  ['()', 'TikTok', '@wonhosexy', '()', 'TikTok',...
# 4  ['Wonho demonstrating how', 'he fell between t...
# 5  ['ل TikTok', '@wonhosexy', 'On this day', '11/...
# 6  ['Me walking around with the', 'most unhinged ...
# 7  ['STAGE', 'WONHO', '1:32', 'ل TikTok', '@wonho...
#
#                                                 sets
# 0  {['TikTok',, '@kimkardashian'], 'ل, TikTok',, ...
# 1  {'@kimkardashian'], ['ل, 'ل, TikTok',, 'TikTok...
# 2  {'@kimkardashian'], 'LOTION',, 'SUNTA',, 'ل, '...
# 3  {'()',, '@wonhosexy'], 'ل, ['()',, 'TikTok',, ...
# 4  {'ل, 'Wonho, 'he, 'the',, ['Wonho, 'ل',, 'demo...
# 5  {'this',, ['ل, 'On, this, day',, '11/16/2021',...
# 6  {'Me, 'walking',, unhinged, the',, 'around',, ...
# 7  {'STAGE',, 'this',, '3/8/2022'], '1:32',, 'On,...

# %%
# Compare every pair of rows and find common strings
for i in range(len(df)):
    for j in range(i + 1, len(df)):
        common_strings = df['sets'][i].intersection(df['sets'][j])
        if common_strings:
            print(f"Common strings between row {i} and row {j}: {common_strings}")
# Out:
# Common strings between row 0 and row 1: {"'@kimkardashian']", "'ل", "'TikTok',", "TikTok',", "'@kimkardashian',", "'ل',"}
# Common strings between row 0 and row 2: {"'@kimkardashian']", "'ل", "'TikTok',", "TikTok',", "'@kimkardashian',", "'ل',"}
# Common strings between row 0 and row 3: {"'ل", "TikTok',", "'TikTok',"}
# Common strings between row 0 and row 4: {"'ل", "'ل',", "'TikTok',", "TikTok',"}
# Common strings between row 0 and row 5: {"'ل", "'ل',", "'TikTok',", "TikTok',"}
# Common strings between row 0 and row 6: {"'ل", "'TikTok',", "TikTok',"}
# Common strings between row 0 and row 7: {"'ل", "'ل',", "'TikTok',", "TikTok',"}
# Common strings between row 1 and row 2: {"'@kimkardashian']", "'ل", "'TikTok',", "TikTok',", "'@kimkardashian',", "'ل',"}
# Common strings between row 1 and row 3: {"'ل", "TikTok',", "'TikTok',"}
# Common strings between row 1 and row 4: {"'ل", "'ل',", "'TikTok',", "TikTok',"}
# Common strings between row 1 and row 5: {"['ل", "'ل", "TikTok',", "'TikTok',", "'ل',"}
# Common strings between row 1 and row 6: {"'ل", "'TikTok',", "TikTok',"}
# Common strings between row 1 and row 7: {"'ل", "'ل',", "'TikTok',", "TikTok',"}
# Common strings between row 2 and row 3: {"'ل", "TikTok',", "'TikTok',"}
# Common strings between row 2 and row 4: {"'ل", "TikTok',", "'ل',", "'TikTok',"}
# Common strings between row 2 and row 5: {"'ل", "TikTok',", "'ل',", "'TikTok',"}
# Common strings between row 2 and row 6: {"'ل", "TikTok',", "'TikTok',"}
# Common strings between row 2 and row 7: {"'ل", "TikTok',", "'ل',", "'TikTok',"}
# Common strings between row 3 and row 4: {"'@wonhosexy']", "'ل", "TikTok',", "'TikTok',", "'@wonhosexy',"}
# Common strings between row 3 and row 5: {"'ل", "TikTok',", "'TikTok',", "'@wonhosexy',"}
# Common strings between row 3 and row 6: {"'@wonhosexy']", "'ل", "TikTok',", "'TikTok',", "'@wonhosexy',"}
# Common strings between row 3 and row 7: {"'ل", "TikTok',", "'TikTok',", "'@wonhosexy',"}
# Common strings between row 4 and row 5: {"'ل", "'TikTok',", "TikTok',", "'@wonhosexy',", "'ل',"}
# Common strings between row 4 and row 6: {"'@wonhosexy']", "'the',", "'ل", "TikTok',", "'TikTok',", "'@wonhosexy',"}
# Common strings between row 4 and row 7: {"'ل", "'TikTok',", "TikTok',", "'@wonhosexy',", "'ل',"}
# Common strings between row 5 and row 6: {"'ل", "'TikTok',", "TikTok',", "'@wonhosexy',"}
# Common strings between row 5 and row 7: {"'@wonhosexy',", "'On", 'this', "day',", "'day',", "'ل", "TikTok',", "'this',", "'TikTok',", "'On',", "'ل',"}
# Common strings between row 6 and row 7: {"'ل", "'TikTok',", "TikTok',", "'@wonhosexy',"}

# %% [markdown]
# #### Text Review
#
# Based on AWS, it looks like the most appeared word is Tiktok, likely from the Tiktok logo tagged in each video. Besides, that the username of the poster the commonly appeared texts.

# %% [markdown]
# ### Part 3 - Celebrity

# %%
df = pd.read_csv('C:\\Users\\Brian\\Desktop\\Tiktok videos\\celebrity.csv')
df
# Out:
#    Index videoID                         celebrity  \
# 0      0      []                                []
# 1      1      []               ['Laura Cremaschi']
# 2      2      []                   ['Huda Kattan']
# 3      3      []  ['Judy Landers', 'Jourdan Dunn']
# 4      4      []                      ['Nie Yuan']
# 5      5      []                    ['Qi Guangpu']
# 6      6      []                                []
# 7      7      []                                []
# 8      8      []        ['Jungkook', 'Bai Jinshi']
#
#                                          furtherinfo
# 0                                                 []
# 1  ['www.wikidata.org/wiki/Q65966463', 'www.imdb....
# 2                ['www.wikidata.org/wiki/Q42966319']
# 3  ['www.imdb.com/name/nm5435984', 'www.wikidata....
# 4  ['www.imdb.com/name/nm1983064', 'www.wikidata....
# 5                  ['www.wikidata.org/wiki/Q955639']
# 6                                                 []
# 7                                                 []
# 8  ['www.wikidata.org/wiki/Q22338877', 'www.wikid...

# %%
# Populate value_count to see if any celebrity appears more than once. If so, suggests commonality between videos 
df['celebrity'].value_counts()
# Out:
# []                                  3
# ['Laura Cremaschi']                 1
# ['Huda Kattan']                     1
# ['Judy Landers', 'Jourdan Dunn']    1
# ['Nie Yuan']                        1
# ['Qi Guangpu']                      1
# ['Jungkook', 'Bai Jinshi']          1
# Name: celebrity, dtype: int64

# %% [markdown]
# #### Celebrity Review
#
# From the value_counts() report, '[]' seems to have 3 instances. This suggests that AWS was not able to detect any celebrities in those video. However, in manually reviewing the outputs, each of the celebrity suggested by Rekognition are incorrect. This is because the sampled videos are from Kim Kardashian and Wonho (see usertags from Part 2 - text Review). It not only misses the correct celebrity but also describes a different celebrity.

# %% [markdown]
# ### Part 4 - Explicit Content detection

# %% [markdown]
# Below is the summarized result of the explicit content review referencing the output results from the code used earlier. If Tag has N/A, this suggests that explicit tag are available but the confidence failed to reach at least 90% threshold. If no problems were detected, 'No Problem Detected' is listed.
#
# | Video  | Tags                  | Confidence above 90% |
# |--------|-----------------------|-----------------------|
# | Kim_1  | Explicit               | 92.21                 |
# | Kim_1  | Explicit Nudity        | 92.21                 |
# | Kim_2  | N/A                    | N/A                   |
# | Kim_3  | N/A                    | N/A                   |
# | Won_1  | N/A                    | N/A                   |
# | Won_2  | No Problem Detected    | N/A                   |
# | Won_3  | No Problem Detected    | N/A                   |
# | Won_4  | N/A                    | N/A                   |

# %% [markdown]
# #### Explicit content review
#
# Based on the algorithm, all the videos except the first one are moderate to mild explicity.

# %% [markdown]
# ### Question 3 Analysis
#
# Based on the findings above, the videos between the two content creators are very different. This seems to suggest and reflect the different target audience between the two celebrities.
#
# | Algorithm       | Similarities                          | Differences                                                   |
# |------------------|---------------------------------------|--------------------------------------------------------------|
# | Labels           | N/A                                   | Content very different. Kim has labels such as underwear, lingerie, outdoor, jewelry, blonde, hair. Wonho has labels such as Indoor, Performer, Happy, Laughing. |
# | Text             | Tiktok logo                           | Username                                                     |
# | Celebrity        | Algorithm could not produce accurate result | Different celebrities generated                               |
# | Explicit Review   | Mildly suggestive content             | Kim has one video marked explicit                                       |

# %% [markdown]
# ## Question 4

# %%
df = pd.read_csv('C:\\Users\\Brian\\Desktop\\Tiktok videos\\Tiktok_numbers.csv')

df
# Out:
#   Video   Follower_Count  Likes   Comment_Count  Bookmarks  \
# 0  Kim_1         9700000  129900           1261       5404
# 1  Kim_2         9700000  119700           2300       8241
# 2  Kim_3         9700000   87000            668       3104
# 3  Won_1           55400   10600             83       1632
# 4  Won_2           55400    3585             31        599
# 5  Won_3           55400     791             20        172
# 6  Won_4           55400  123500            660      11300
# 7  Won_5           55400    1377             18        209
#
#                                             Comments
# 0  "That’s how I dress for the gym too","Is this ...
# 1  "Salma Hayek Nailed it","beautiful salma","Omh...
# 2  "I am a really a big fan of yours Kim Kardashi...
# 3  "My name is Regina","Beautiful 🔥🔥🔥🥰🥰🥰🥰😍😍😍😍","e...
# 4  "HE KNOWS WHAT HES DOING AND I APPRECIATE IT",...
# 5  "this felt illegal to watch n for him to post ...
# 6  "CROP","When I tell you my jaw DROPPED","I hav...
# 7  "Can I have that job🤭","how many people applie...

# %%
# To make the comparison fair, we will adjust for follower count by dividing the likes, comments, and bookmarks. 

df['Likes '] = df['Likes ']/df['Follower_Count']
df['Comment_Count'] = df['Comment_Count']/df['Follower_Count']
df['Bookmarks'] = df['Bookmarks']/df['Follower_Count']

df
# Out:
#   Video   Follower_Count    Likes   Comment_Count  Bookmarks  \
# 0  Kim_1         9700000  0.013392       0.000130   0.000557
# 1  Kim_2         9700000  0.012340       0.000237   0.000850
# 2  Kim_3         9700000  0.008969       0.000069   0.000320
# 3  Won_1           55400  0.191336       0.001498   0.029458
# 4  Won_2           55400  0.064711       0.000560   0.010812
# 5  Won_3           55400  0.014278       0.000361   0.003105
# 6  Won_4           55400  2.229242       0.011913   0.203971
# 7  Won_5           55400  0.024856       0.000325   0.003773
#
#                                             Comments
# 0  "That’s how I dress for the gym too","Is this ...
# 1  "Salma Hayek Nailed it","beautiful salma","Omh...
# 2  "I am a really a big fan of yours Kim Kardashi...
# 3  "My name is Regina","Beautiful 🔥🔥🔥🥰🥰🥰🥰😍😍😍😍","e...
# 4  "HE KNOWS WHAT HES DOING AND I APPRECIATE IT",...
# 5  "this felt illegal to watch n for him to post ...
# 6  "CROP","When I tell you my jaw DROPPED","I hav...
# 7  "Can I have that job🤭","how many people applie...

# %%
label_df = pd.read_csv('C:\\Users\\Brian\\Desktop\\Tiktok videos\\labels.csv')
label_df.head(5)
# Out:
#    Index         videoname  labels  confidencescores  timestamps
# 0      0  videos/Kim_1.mp4    Male         90.295975       38700
# 1      1  videos/Kim_1.mp4     Man         90.084686       38700
# 2      2  videos/Kim_1.mp4  Person         96.893768       38700
# 3      3  videos/Kim_1.mp4   Adult         97.542847       39200
# 4      4  videos/Kim_1.mp4  Female         92.632309       39200

# %%
# Isolate name of each video 
label_df['Video'] = label_df['videoname'].str.extract(r'/(.*)\.mp4')
label_df.head(5)
# Out:
#    Index         videoname  labels  confidencescores  timestamps  Video
# 0      0  videos/Kim_1.mp4    Male         90.295975       38700  Kim_1
# 1      1  videos/Kim_1.mp4     Man         90.084686       38700  Kim_1
# 2      2  videos/Kim_1.mp4  Person         96.893768       38700  Kim_1
# 3      3  videos/Kim_1.mp4   Adult         97.542847       39200  Kim_1
# 4      4  videos/Kim_1.mp4  Female         92.632309       39200  Kim_1

# %%
# Aggregate labels

df_combined_label = label_df.groupby('Video').agg({
    'videoname': 'first',
    'labels': ', '.join,
    'confidencescores': lambda x: ', '.join(x.astype(str)),
    'timestamps': lambda x: ', '.join(x.astype(str))
}).reset_index()

df_combined_label.head(5)
# Out:
#    Video         videoname                                             labels  \
# 0  Kim_1  videos/Kim_1.mp4  Male, Man, Person, Adult, Female, Woman, Body ...
# 1  Kim_2  videos/Kim_2.mp4  Face, Head, Underwear, Swimwear, Lingerie, Bra...
# 2  Kim_3  videos/Kim_3.mp4  Accessories, Earring, Jewelry, Blonde, Hair, W...
# 3  Won_1  videos/Won_1.mp4  Baby, Fitness, Gym, Gym Weights, Sport, Workin...
# 4  Won_2  videos/Won_2.mp4  Coat, Cushion, Home Decor, Indoors, Interior D...
#
#                                     confidencescores  \
# 0  90.29597473144533, 90.08468627929688, 96.89376...
# 1  92.20004272460938, 92.6380386352539, 92.070762...
# 2  97.35279083251952, 97.29650115966795, 97.29650...
# 3  90.79158020019533, 90.12174224853516, 90.12174...
# 4  90.61336517333984, 91.1993179321289, 91.516601...
#
#                                           timestamps
# 0  38700, 38700, 38700, 39200, 39200, 39200, 4020...
# 1  33766, 33766, 35766, 36266, 36766, 37266, 3826...
# 2           21521, 21521, 21521, 23523, 23523, 23523
# 3           2533, 4516, 4516, 4516, 4516, 4516, 5516
# 4           59933, 59933, 59933, 60433, 60433, 60933

# %%
print(df.columns)
print(df_combined_label.columns)
# Out:
# Index(['Video ', 'Follower_Count', 'Likes ', 'Comment_Count', 'Bookmarks',
#        'Comments'],
#       dtype='object')
# Index(['Video', 'videoname', 'labels', 'confidencescores', 'timestamps'], dtype='object')

# %%
df.rename(columns={'Video ':'Video'},inplace=True)
df.columns
# Out:
# Index(['Video', 'Follower_Count', 'Likes ', 'Comment_Count', 'Bookmarks',
#        'Comments'],
#       dtype='object')

# %%
# Merging dataframes between the label analysis and Tiktok data 

main_df = pd.merge(df, df_combined_label, on=['Video'], how='inner')
main_df
# Out:
#    Video  Follower_Count    Likes   Comment_Count  Bookmarks  \
# 0  Kim_1         9700000  0.013392       0.000130   0.000557
# 1  Kim_2         9700000  0.012340       0.000237   0.000850
# 2  Kim_3         9700000  0.008969       0.000069   0.000320
# 3  Won_1           55400  0.191336       0.001498   0.029458
# 4  Won_2           55400  0.064711       0.000560   0.010812
# 5  Won_3           55400  0.014278       0.000361   0.003105
# 6  Won_4           55400  2.229242       0.011913   0.203971
# 7  Won_5           55400  0.024856       0.000325   0.003773
#
#                                             Comments         videoname  \
# 0  "That’s how I dress for the gym too","Is this ...  videos/Kim_1.mp4
# 1  "Salma Hayek Nailed it","beautiful salma","Omh...  videos/Kim_2.mp4
# 2  "I am a really a big fan of yours Kim Kardashi...  videos/Kim_3.mp4
# 3  "My name is Regina","Beautiful 🔥🔥🔥🥰🥰🥰🥰😍😍😍😍","e...  videos/Won_1.mp4
# 4  "HE KNOWS WHAT HES DOING AND I APPRECIATE IT",...  videos/Won_2.mp4
# 5  "this felt illegal to watch n for him to post ...  videos/Won_3.mp4
# 6  "CROP","When I tell you my jaw DROPPED","I hav...  videos/Won_4.mp4
# 7  "Can I have that job🤭","how many people applie...  videos/Won_5.mp4
#
#                                               labels  \
# 0  Male, Man, Person, Adult, Female, Woman, Body ...
# 1  Face, Head, Underwear, Swimwear, Lingerie, Bra...
# 2  Accessories, Earring, Jewelry, Blonde, Hair, W...
# 3  Baby, Fitness, Gym, Gym Weights, Sport, Workin...
# 4  Coat, Cushion, Home Decor, Indoors, Interior D...
# 5                                      Boy, Romantic
# 6                        Performer, Solo Performance
# 7                      Happy, Laughing, Eating, Food
#
#                                     confidencescores  \
# 0  90.29597473144533, 90.08468627929688, 96.89376...
# 1  92.20004272460938, 92.6380386352539, 92.070762...
# 2  97.35279083251952, 97.29650115966795, 97.29650...
# 3  90.79158020019533, 90.12174224853516, 90.12174...
# 4  90.61336517333984, 91.1993179321289, 91.516601...
# 5               90.18084716796876, 90.68704223632812
# 6               99.99828338623048, 99.99828338623048
# 7  95.04277801513672, 94.8965072631836, 91.308601...
#
#                                           timestamps
# 0  38700, 38700, 38700, 39200, 39200, 39200, 4020...
# 1  33766, 33766, 35766, 36266, 36766, 37266, 3826...
# 2           21521, 21521, 21521, 23523, 23523, 23523
# 3           2533, 4516, 4516, 4516, 4516, 4516, 5516
# 4           59933, 59933, 59933, 60433, 60433, 60933
# 5                                        2033, 12500
# 6                                               0, 0
# 7                               520, 520, 5520, 5520

# %%
# Sort table with most likes at the top and least likes at the bottom

main_df = main_df.sort_values(by='Likes ', ascending=False)  # Sort in descending order for highest Likes first
main_df
# Out:
#    Video  Follower_Count    Likes   Comment_Count  Bookmarks  \
# 6  Won_4           55400  2.229242       0.011913   0.203971
# 3  Won_1           55400  0.191336       0.001498   0.029458
# 4  Won_2           55400  0.064711       0.000560   0.010812
# 7  Won_5           55400  0.024856       0.000325   0.003773
# 5  Won_3           55400  0.014278       0.000361   0.003105
# 0  Kim_1         9700000  0.013392       0.000130   0.000557
# 1  Kim_2         9700000  0.012340       0.000237   0.000850
# 2  Kim_3         9700000  0.008969       0.000069   0.000320
#
#                                             Comments         videoname  \
# 6  "CROP","When I tell you my jaw DROPPED","I hav...  videos/Won_4.mp4
# 3  "My name is Regina","Beautiful 🔥🔥🔥🥰🥰🥰🥰😍😍😍😍","e...  videos/Won_1.mp4
# 4  "HE KNOWS WHAT HES DOING AND I APPRECIATE IT",...  videos/Won_2.mp4
# 7  "Can I have that job🤭","how many people applie...  videos/Won_5.mp4
# 5  "this felt illegal to watch n for him to post ...  videos/Won_3.mp4
# 0  "That’s how I dress for the gym too","Is this ...  videos/Kim_1.mp4
# 1  "Salma Hayek Nailed it","beautiful salma","Omh...  videos/Kim_2.mp4
# 2  "I am a really a big fan of yours Kim Kardashi...  videos/Kim_3.mp4
#
#                                               labels  \
# 6                        Performer, Solo Performance
# 3  Baby, Fitness, Gym, Gym Weights, Sport, Workin...
# 4  Coat, Cushion, Home Decor, Indoors, Interior D...
# 7                      Happy, Laughing, Eating, Food
# 5                                      Boy, Romantic
# 0  Male, Man, Person, Adult, Female, Woman, Body ...
# 1  Face, Head, Underwear, Swimwear, Lingerie, Bra...
# 2  Accessories, Earring, Jewelry, Blonde, Hair, W...
#
#                                     confidencescores  \
# 6               99.99828338623048, 99.99828338623048
# 3  90.79158020019533, 90.12174224853516, 90.12174...
# 4  90.61336517333984, 91.1993179321289, 91.516601...
# 7  95.04277801513672, 94.8965072631836, 91.308601...
# 5               90.18084716796876, 90.68704223632812
# 0  90.29597473144533, 90.08468627929688, 96.89376...
# 1  92.20004272460938, 92.6380386352539, 92.070762...
# 2  97.35279083251952, 97.29650115966795, 97.29650...
#
#                                           timestamps
# 6                                               0, 0
# 3           2533, 4516, 4516, 4516, 4516, 4516, 5516
# 4           59933, 59933, 59933, 60433, 60433, 60933
# 7                               520, 520, 5520, 5520
# 5                                        2033, 12500
# 0  38700, 38700, 38700, 39200, 39200, 39200, 4020...
# 1  33766, 33766, 35766, 36266, 36766, 37266, 3826...
# 2           21521, 21521, 21521, 23523, 23523, 23523

# %% [markdown]
# #### Analysis of Likes
#
# Based on the most number of likes, the top video with an average of 2.2 likes per follower seems to be about a performance as suggested by the labels. Contrast to this, the video with least amount of likes (0.009) seems to be about showing off fashion or jewelry with labels such as accessories, earrings, jewelry, blonde, hair.
#
# This implies that performance's wow factor impresses a lot of people, as opposed to showing off a personal fashion statement.

# %%
# Sort table with most comments at the top and least likes at the bottom

main_df = main_df.sort_values(by='Comment_Count', ascending=False)  # Sort in descending order for highest Likes first
main_df
# Out:
#    Video  Follower_Count    Likes   Comment_Count  Bookmarks  \
# 6  Won_4           55400  2.229242       0.011913   0.203971
# 3  Won_1           55400  0.191336       0.001498   0.029458
# 4  Won_2           55400  0.064711       0.000560   0.010812
# 5  Won_3           55400  0.014278       0.000361   0.003105
# 7  Won_5           55400  0.024856       0.000325   0.003773
# 1  Kim_2         9700000  0.012340       0.000237   0.000850
# 0  Kim_1         9700000  0.013392       0.000130   0.000557
# 2  Kim_3         9700000  0.008969       0.000069   0.000320
#
#                                             Comments         videoname  \
# 6  "CROP","When I tell you my jaw DROPPED","I hav...  videos/Won_4.mp4
# 3  "My name is Regina","Beautiful 🔥🔥🔥🥰🥰🥰🥰😍😍😍😍","e...  videos/Won_1.mp4
# 4  "HE KNOWS WHAT HES DOING AND I APPRECIATE IT",...  videos/Won_2.mp4
# 5  "this felt illegal to watch n for him to post ...  videos/Won_3.mp4
# 7  "Can I have that job🤭","how many people applie...  videos/Won_5.mp4
# 1  "Salma Hayek Nailed it","beautiful salma","Omh...  videos/Kim_2.mp4
# 0  "That’s how I dress for the gym too","Is this ...  videos/Kim_1.mp4
# 2  "I am a really a big fan of yours Kim Kardashi...  videos/Kim_3.mp4
#
#                                               labels  \
# 6                        Performer, Solo Performance
# 3  Baby, Fitness, Gym, Gym Weights, Sport, Workin...
# 4  Coat, Cushion, Home Decor, Indoors, Interior D...
# 5                                      Boy, Romantic
# 7                      Happy, Laughing, Eating, Food
# 1  Face, Head, Underwear, Swimwear, Lingerie, Bra...
# 0  Male, Man, Person, Adult, Female, Woman, Body ...
# 2  Accessories, Earring, Jewelry, Blonde, Hair, W...
#
#                                     confidencescores  \
# 6               99.99828338623048, 99.99828338623048
# 3  90.79158020019533, 90.12174224853516, 90.12174...
# 4  90.61336517333984, 91.1993179321289, 91.516601...
# 5               90.18084716796876, 90.68704223632812
# 7  95.04277801513672, 94.8965072631836, 91.308601...
# 1  92.20004272460938, 92.6380386352539, 92.070762...
# 0  90.29597473144533, 90.08468627929688, 96.89376...
# 2  97.35279083251952, 97.29650115966795, 97.29650...
#
#                                           timestamps
# 6                                               0, 0
# 3           2533, 4516, 4516, 4516, 4516, 4516, 5516
# 4           59933, 59933, 59933, 60433, 60433, 60933
# 5                                        2033, 12500
# 7                               520, 520, 5520, 5520
# 1  33766, 33766, 35766, 36266, 36766, 37266, 3826...
# 0  38700, 38700, 38700, 39200, 39200, 39200, 4020...
# 2           21521, 21521, 21521, 23523, 23523, 23523

# %%
# Remove truncate effect of jupyter
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows


print("\n Most engagement comments \n")

comments_series = main_df.iloc[0,5:6].values[0]
comments_list = comments_series.strip('"').split('","')
comments_list = [comment.strip('"') for comment in comments_list]

for comments in comments_list:
    print(comments)
    
    
    
print("\n Least engagement comments \n")

comments_series = main_df.iloc[7,5:6].values[0]
comments_list = comments_series.strip('"').split('","')
comments_list = [comment.strip('"') for comment in comments_list]

for comments in comments_list:
    print(comments)
# Out:
#  Most engagement comments
#
# CROP
# When I tell you my jaw DROPPED
# I have the one where he just wears a towel wrapped around his waist.
# He's so beautiful 😭🫶🏾
# Aww miss his ig posts 😩 military service killing us all
#
#  Least engagement comments
#
# I am a really a big fan of yours Kim Kardashian yep
# 📞 still in 2022? 👀🎾🕊
# KAREN WHEELER KIM ?????
# Giving Kim in the 80s vibes 😍🤍
# slayed the 80s vibes

# %% [markdown]
# #### Analysis of Comments
# The reel with the most comments and the least are also the same for likes. Top video has 0.011913 comments per follower, while worst video has 0.000069	per follower. The video with most engagement, as expected, has comments about the performance regarding the wow factor using words like "jaw dropped" and a series of other fan sentiments. With the least engaging video, most comments involve guessing the style with words like "2022 and 80's vibe."
#
# Comments like these may suggest that a more dynamic video is likely to prompt more engagement from users.

# %%
# Sort table with most Bookmarks at the top and least likes at the bottom

main_df = main_df.sort_values(by='Bookmarks', ascending=False)  # Sort in descending order for highest Likes first
main_df
# Out:
#    Video  Follower_Count    Likes   Comment_Count  Bookmarks  \
# 6  Won_4           55400  2.229242       0.011913   0.203971
# 3  Won_1           55400  0.191336       0.001498   0.029458
# 4  Won_2           55400  0.064711       0.000560   0.010812
# 7  Won_5           55400  0.024856       0.000325   0.003773
# 5  Won_3           55400  0.014278       0.000361   0.003105
# 1  Kim_2         9700000  0.012340       0.000237   0.000850
# 0  Kim_1         9700000  0.013392       0.000130   0.000557
# 2  Kim_3         9700000  0.008969       0.000069   0.000320
#
#                                                                                                                                                                                                                                                             Comments  \
# 6                                                                   "CROP","When I tell you my jaw DROPPED","I have the one where he just wears a towel wrapped around his waist.","He's so beautiful 😭🫶🏾","Aww miss his ig posts 😩 military service killing us all"
# 3                                                                                    "My name is Regina","Beautiful 🔥🔥🔥🥰🥰🥰🥰😍😍😍😍","either watch again after so many times or stare big titty chest probably both","@Larry-Shit OMGGGG","I have... I- I have THOUGHTS"
# 4                                                                "HE KNOWS WHAT HES DOING AND I APPRECIATE IT","I am but a humble watermelon to be crushed","I feel I should be paying for this 😳","Yes. We’re all paying attention to the demonstration…","QUADS 🤯"
# 7                                                                                                                                                  "Can I have that job🤭","how many people applied for that job","Ooo my","I miss it! 😀","El trabajo que necesito 😭"
# 5                                                                         "this felt illegal to watch n for him to post that n went to jail happily after watching this 😌","I was literally ab to post this 🙏😭","🥵🥵🥵🥵🥵🥵","💋💋💋💋💋💋🥰🥰💘","The reason was to distress us"
# 1                                                                                                                                                                                                    "Salma Hayek Nailed it","beautiful salma","Omh","Yesssss","wow"
# 0  "That’s how I dress for the gym too","Is this your Britney Spears era","I wore that same thing to the gym yesterday","This a breakup revenge video what did he do!!???","She’s an energy vampire she fed off of Pete and is becoming more powerful and beautiful"
# 2                                                                                                     "I am a really a big fan of yours Kim Kardashian yep","📞 still in 2022? 👀🎾🕊","KAREN WHEELER KIM ?????","Giving Kim in the 80s vibes 😍🤍","slayed the 80s vibes"
#
#           videoname  \
# 6  videos/Won_4.mp4
# 3  videos/Won_1.mp4
# 4  videos/Won_2.mp4
# 7  videos/Won_5.mp4
# 5  videos/Won_3.mp4
# 1  videos/Kim_2.mp4
# 0  videos/Kim_1.mp4
# 2  videos/Kim_3.mp4
#
#                                                                                     labels  \
# 6                                                              Performer, Solo Performance
# 3                         Baby, Fitness, Gym, Gym Weights, Sport, Working Out, Bench Press
# 4                               Coat, Cushion, Home Decor, Indoors, Interior Design, Shirt
# 7                                                            Happy, Laughing, Eating, Food
# 5                                                                            Boy, Romantic
# 1  Face, Head, Underwear, Swimwear, Lingerie, Bra, Photography, Portrait, Nature, Outdoors
# 0                      Male, Man, Person, Adult, Female, Woman, Body Part, Torso, Clothing
# 2                                     Accessories, Earring, Jewelry, Blonde, Hair, Wedding
#
#                                                                                                                                                                             confidencescores  \
# 6                                                                                                                                                       99.99828338623048, 99.99828338623048
# 3                                                        90.79158020019533, 90.12174224853516, 90.12174224853516, 90.12174224853516, 90.12174224853516, 90.12174224853516, 93.14005279541016
# 4                                                                                90.61336517333984, 91.1993179321289, 91.5166015625, 97.29479217529295, 97.29479217529295, 93.06817626953124
# 7                                                                                                                  95.04277801513672, 94.8965072631836, 91.30860137939452, 91.30860137939452
# 5                                                                                                                                                       90.18084716796876, 90.68704223632812
# 1  92.20004272460938, 92.6380386352539, 92.07076263427734, 90.20240783691406, 92.28104400634766, 94.37992095947266, 90.3376235961914, 90.3376235961914, 95.35426330566406, 96.16068267822266
# 0                   90.29597473144533, 90.08468627929688, 96.89376831054688, 97.5428466796875, 92.63230895996094, 92.63230895996094, 90.24151611328124, 90.22171783447266, 92.47262573242188
# 2                                                                           97.35279083251952, 97.29650115966795, 97.29650115966795, 97.02468872070312, 97.02468872070312, 93.59627532958984
#
#                                                              timestamps
# 6                                                                  0, 0
# 3                              2533, 4516, 4516, 4516, 4516, 4516, 5516
# 4                              59933, 59933, 59933, 60433, 60433, 60933
# 7                                                  520, 520, 5520, 5520
# 5                                                           2033, 12500
# 1  33766, 33766, 35766, 36266, 36766, 37266, 38266, 38266, 48266, 48266
# 0         38700, 38700, 38700, 39200, 39200, 39200, 40200, 40200, 41200
# 2                              21521, 21521, 21521, 23523, 23523, 23523

# %% [markdown]
# #### Analysis of bookmarks
#
# As demonstrated with the other engagement performance indicators, bookmarks are highest for the video that has a performance and lowest for the fashion statement.
#
# This may suggest that the performance video has more re-watch value and merits a bookmark to return to it. In contrast, fashion videos are more of a passing interest and viewers do not find so much value in keeping it.

# %% [markdown]
# ### Conclusion
#
# Based on the tags pulled from AWS Sagemaker and Tiktok metrics, videos involving performances have a wow factor that draws more engagements and has re-watch values for users. This is for when the data is controlled for other factors like reach, where Kim Kardashian has a larger audience than Wonho. However, when reach is not controlled, Kim will have more actual engagement than Wonho.
#
# This might suggest that there is a larger market for media influencers like Kim Kardashian, who has built her career on social media and press. Whereas Wonho is a celebrity for a niche music market, which may have less of a draw because of its specialized market.

# %% [markdown]
# ## Question 5

# %% [markdown]
# Results from Explicit Content review
#
# | Video  | Tags                  | Confidence above 90% |
# |--------|-----------------------|-----------------------|
# | Kim_1  | Explicit               | 92.21                 |
# | Kim_1  | Explicit Nudity        | 92.21                 |
# | Kim_2  | N/A                    | N/A                   |
# | Kim_3  | N/A                    | N/A                   |
# | Won_1  | N/A                    | N/A                   |
# | Won_2  | No Problem Detected    | N/A                   |
# | Won_3  | No Problem Detected    | N/A                   |
# | Won_4  | N/A                    | N/A                   |

# %%
# Extracting comments from Kim_1 (Explicit video)
main_df.loc[[0], :]
# Out:
#    Video  Follower_Count    Likes   Comment_Count  Bookmarks  \
# 0  Kim_1         9700000  0.013392        0.00013   0.000557
#
#                                                                                                                                                                                                                                                             Comments  \
# 0  "That’s how I dress for the gym too","Is this your Britney Spears era","I wore that same thing to the gym yesterday","This a breakup revenge video what did he do!!???","She’s an energy vampire she fed off of Pete and is becoming more powerful and beautiful"
#
#           videoname  \
# 0  videos/Kim_1.mp4
#
#                                                                 labels  \
# 0  Male, Man, Person, Adult, Female, Woman, Body Part, Torso, Clothing
#
#                                                                                                                                                            confidencescores  \
# 0  90.29597473144533, 90.08468627929688, 96.89376831054688, 97.5428466796875, 92.63230895996094, 92.63230895996094, 90.24151611328124, 90.22171783447266, 92.47262573242188
#
#                                                       timestamps
# 0  38700, 38700, 38700, 39200, 39200, 39200, 40200, 40200, 41200

# %%
print("\n Explicit flagged comments \n")

comments_series = main_df.iloc[6,5:6].values[0]
comments_list = comments_series.strip('"').split('","')
comments_list = [comment.strip('"') for comment in comments_list]

for comments in comments_list:
    print(comments)
    
print("\n Explicit tags \n")

labels_series = main_df.iloc[6,7:8].values[0]
labels_list = labels_series.strip('"').split('","')
labels_list = [tag.strip('"') for tag in labels_list]

for tag in labels_list:
    print(tag)
# Out:
#  Explicit flagged comments
#
# That’s how I dress for the gym too
# Is this your Britney Spears era
# I wore that same thing to the gym yesterday
# This a breakup revenge video what did he do!!???
# She’s an energy vampire she fed off of Pete and is becoming more powerful and beautiful
#
#  Explicit tags
#
# Male, Man, Person, Adult, Female, Woman, Body Part, Torso, Clothing

# %% [markdown]
# ### Review
#
# #### Analysis of flagged content
# Only one video of the eight were tagged as explicit, with the algorithm finding confidence levels above 90% for labels like "Male, Man, Female, Woman, Body Part, Torso, Clothing." This seems to be very suggestive. Looking at a few of the comments, it seems to rather suggest that this might be more related to gym with comments like "how I dress for gym, wore that same thing to the gym" and words like "breakup revenge" and "powerful and beautiful". The latter two aligning with the common sentiment of a glow-up, of which gyms and exercise are essential.
#
# Based on these comments and the various tags, this seems to be more of a fitness video with possibly minimal clothing. While it is not necessarily nudity, the algorithm has flagged it as so with 92% confidence. Since this video is still uploaded and public on TikTok, it seems that TikTok is fair in its judgment of explicit content and not too restrictive. This seems to be a false positive, meaning that the algorithm has passed it for nudity when it isn't.
#
# Below, I decided to take it one step further and check for false negatives. Parsing through the comments, I decided to pick one video that might seem to have a suggestive draw.

# %%
#### Review of Video Won_1 (potential suggestive draw)

print("\n Not-flagged comments \n")

comments_series = main_df.iloc[1,5:6].values[0]
comments_list = comments_series.strip('"').split('","')
comments_list = [comment.strip('"') for comment in comments_list]

for comments in comments_list:
    print(comments)
    
print("\n Not-flagged tags \n")

labels_series = main_df.iloc[1,7:8].values[0]
labels_list = labels_series.strip('"').split('","')
labels_list = [tag.strip('"') for tag in labels_list]

for tag in labels_list:
    print(tag)
# Out:
#  Not-flagged comments
#
# My name is Regina
# Beautiful 🔥🔥🔥🥰🥰🥰🥰😍😍😍😍
# either watch again after so many times or stare big titty chest probably both
# @Larry-Shit OMGGGG
# I have... I- I have THOUGHTS
#
#  Not-flagged tags
#
# Baby, Fitness, Gym, Gym Weights, Sport, Working Out, Bench Press

# %% [markdown]
# #### Analysis of potential false negative
#
# In this video, we get comments like "🔥🔥🔥", "stare big titty chest", "OMGGGG" and "I- I have THOUGHTS." These are highly reactive comments and seems to suggest inappopriate or suggestive content. However, looking at the tags from Sagemaker, it looks like the video has various tags related to gym such as "Fitness, Gym, Gym Weights, Sport, Working Out, Bench Press" with confidence scores in the 90% range. This implies that, while it might have elicited a strong reaction from the fans and display some evocative images, it is not an inappropriate video and does not have any explicit contents. As such, it is a true negative.
#
# As a general conclusion, Tik Tok is doing a good job with its moderation of explicit content and based on the videos sampled, does not have any false negatives or false positives.

# %% [markdown]
# ## Question 6
#
# Kim Kardashian, who has a big social media presence already, could take further steps to improve her engagement. While she is doing well by raw metrics like aggregate likes, views, or comments, it is much lower if adjusted for following size. Compared to her followings, she has a relatively low engagement. To improve her engagements, she may upload more active or entertaining videos. This could be like a makeup tutorial or a review of a luxury brand. Videos like those have more re-watch value because users can mimic makeup or research the luxury brand, for instance. As such, more users will bookmark and engage. They may comment questions like "What is that brand" or press like to get more quality shorts like that.
#
# Wonho, having a smaller social media presence, could focus on increasing his media presence. While he has very good engagments already with his current followers, he can further improve by having more collaboration with other celebrities active on social media. This will be a good way to expand reach since the algorithm will introduce him to a new group of audience that previously do not know of him.

# %% [markdown]
# # Question 7
# See powerpoint.
